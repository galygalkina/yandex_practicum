# %% [markdown]
# # Выпускной проект "Модель монетизации игрового приложения"

# %% [markdown]
# ## Материалы:
#
# * [Презентация] (https://drive.google.com/file/d/1WvHd-sJ2Pfx03AsPvWCjbLXZ2UjzPt4o/view?usp=sharing)
# * [Дашборд] (https://public.tableau.com/app/profile/galina.galkina5794/viz/_16258726999010/Dashboard1 )

# %% [markdown]
# В рамках выпускного проекта поставлена задача сформировать модель монетизации игрового приложения «Космические братья». В мобильной игре пользователи строят свою космическую программу и пытаются преуспеть в нелёгком деле колонизации галактики.
#
# По условияю задачи создатели игры предварительно думают показывать рекламу на экране с выбором типа объекта для постройки.
#
# В датасете представлены данные по игре пользователей на первом уровне. Завершение первого уровня требует от игрока выполнения одного из двух условий:
#
#  - Победа над первым врагом
#  - Реализация проекта - разработка орбитальной сборки спутников
#
# Исследование будем проводить в несколько шагов.
#
#  - Загрузка основного датасета с данными первых пользователей приложения и двух дополнительных датасетов с информацией о рекламных активностях.
#
#  - Подготовка данных к исследованию:
#
#    - Проверка на наличие дубликатов в датасетах
#    - Рассмотрение каждого столбца каждого датасета по отдельности, выявление пропущенных и подозрительных значений и ошибок. Рассмотрение уникальных значений и числовых описаний.
#
#  - Исследовательский анализ данных
#    - Среднее время прохождения уровня
#    - Количество построек на каждого пользователя
#    - Сколько раз за день пользователи в среднем заходят в мобильное приложение
#    - Показатели вовлечённости - DAU, WAU, Sticky Factor
#    - Коэффициент удержания Retention Rate
#    - Стоимость привлечения клиента CAC
#
#  - Проверка статистических гипотез
#    - Гипотеза различия времени прохождения уровня
#    - Гипотеза различия количества построенных зданий
#
# В завершении напишем общий вывод и сформулируем рекомендации.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Материалы:" data-toc-modified-id="Материалы:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Материалы:</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-тимлида" data-toc-modified-id="Комментарий-от-тимлида-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Комментарий от тимлида</a></span></li><li><span><a href="#Комментарий-от-тимлида-v3" data-toc-modified-id="Комментарий-от-тимлида-v3-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Комментарий от тимлида v3</a></span></li></ul></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Подготовка-данных-к-исследованию" data-toc-modified-id="Подготовка-данных-к-исследованию-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Подготовка данных к исследованию</a></span><ul class="toc-item"><li><span><a href="#Таблица-game_actions-с-данными-первых-пользователей-приложения" data-toc-modified-id="Таблица-game_actions-с-данными-первых-пользователей-приложения-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Таблица <code>game_actions</code> с данными первых пользователей приложения</a></span><ul class="toc-item"><li><span><a href="#Столбец-event_datetime---время-события" data-toc-modified-id="Столбец-event_datetime---время-события-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Столбец <code>event_datetime</code> - время события</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Комментарий-от-тимлида" data-toc-modified-id="Комментарий-от-тимлида-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Комментарий от тимлида</a></span><ul class="toc-item"><li><span><a href="#Столбец-event---событие" data-toc-modified-id="Столбец-event---событие-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Столбец <code>event</code> - событие</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Столбец-building_type---тип-здания" data-toc-modified-id="Столбец-building_type---тип-здания-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Столбец <code>building_type</code> - тип здания</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Столбец-user_id---идентификатор-пользователя" data-toc-modified-id="Столбец-user_id---идентификатор-пользователя-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Столбец <code>user_id</code> - идентификатор пользователя</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Столбец-project_type---тип-реализованного-проекта" data-toc-modified-id="Столбец-project_type---тип-реализованного-проекта-4.2.7"><span class="toc-item-num">4.2.7&nbsp;&nbsp;</span>Столбец <code>project_type</code> - тип реализованного проекта</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.8"><span class="toc-item-num">4.2.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Таблица-ad_costs-с-информацией-о-рекламных-активностях" data-toc-modified-id="Таблица-ad_costs-с-информацией-о-рекламных-активностях-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Таблица <code>ad_costs</code> с информацией о рекламных активностях</a></span><ul class="toc-item"><li><span><a href="#Столбец-source---источник-трафика" data-toc-modified-id="Столбец-source---источник-трафика-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Столбец <code>source</code> - источник трафика</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Столбец-day---день,-в-который-был-совершен-клик-по-объявлению" data-toc-modified-id="Столбец-day---день,-в-который-был-совершен-клик-по-объявлению-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Столбец <code>day</code> - день, в который был совершен клик по объявлению</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Столбец-cost---стоимость-кликов" data-toc-modified-id="Столбец-cost---стоимость-кликов-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Столбец <code>cost</code> - стоимость кликов</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3.6"><span class="toc-item-num">4.3.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Таблица-user_source-с-информацией-о-рекламных-активностях" data-toc-modified-id="Таблица-user_source-с-информацией-о-рекламных-активностях-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Таблица <code>user_source</code> с информацией о рекламных активностях</a></span><ul class="toc-item"><li><span><a href="#Столбец-user_id---идентификатор-пользователя" data-toc-modified-id="Столбец-user_id---идентификатор-пользователя-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Столбец <code>user_id</code> - идентификатор пользователя</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Столбец-source---источник,-с-которого-пришёл-пользователь,-установивший-приложение" data-toc-modified-id="Столбец-source---источник,-с-которого-пришёл-пользователь,-установивший-приложение-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Столбец <code>source</code> - источник, с которого пришёл пользователь, установивший приложение</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Среднее-время-прохождения-уровня" data-toc-modified-id="Среднее-время-прохождения-уровня-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Среднее время прохождения уровня</a></span></li><li><span><a href="#Комментарий-от-тимлида" data-toc-modified-id="Комментарий-от-тимлида-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Комментарий от тимлида</a></span></li><li><span><a href="#Комментарий-от-тимлида-v3" data-toc-modified-id="Комментарий-от-тимлида-v3-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Комментарий от тимлида v3</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Комментарий-от-тимлида" data-toc-modified-id="Комментарий-от-тимлида-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Комментарий от тимлида</a></span></li><li><span><a href="#Комментарий-от-тимлида--v2" data-toc-modified-id="Комментарий-от-тимлида--v2-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Комментарий от тимлида  v2</a></span></li><li><span><a href="#Количество-построек-на-каждого-пользователя" data-toc-modified-id="Количество-построек-на-каждого-пользователя-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Количество построек на каждого пользователя</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Комментарий-от-тимлида" data-toc-modified-id="Комментарий-от-тимлида-6.9"><span class="toc-item-num">6.9&nbsp;&nbsp;</span>Комментарий от тимлида</a></span></li><li><span><a href="#Комментарий-от-тимлида-v3" data-toc-modified-id="Комментарий-от-тимлида-v3-6.10"><span class="toc-item-num">6.10&nbsp;&nbsp;</span>Комментарий от тимлида v3</a></span></li><li><span><a href="#Сколько-раз-за-день-пользователи-в-среднем-заходят-в-мобильное-приложение" data-toc-modified-id="Сколько-раз-за-день-пользователи-в-среднем-заходят-в-мобильное-приложение-6.11"><span class="toc-item-num">6.11&nbsp;&nbsp;</span>Сколько раз за день пользователи в среднем заходят в мобильное приложение</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.12"><span class="toc-item-num">6.12&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Показатели-вовлечённости---DAU,-WAU,-Sticky-Factor" data-toc-modified-id="Показатели-вовлечённости---DAU,-WAU,-Sticky-Factor-6.13"><span class="toc-item-num">6.13&nbsp;&nbsp;</span>Показатели вовлечённости - DAU, WAU, Sticky Factor</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.14"><span class="toc-item-num">6.14&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Комментарий-от-тимлида" data-toc-modified-id="Комментарий-от-тимлида-6.15"><span class="toc-item-num">6.15&nbsp;&nbsp;</span>Комментарий от тимлида</a></span></li><li><span><a href="#Коэффициент-удержания-Retention-Rate" data-toc-modified-id="Коэффициент-удержания-Retention-Rate-6.16"><span class="toc-item-num">6.16&nbsp;&nbsp;</span>Коэффициент удержания Retention Rate</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.17"><span class="toc-item-num">6.17&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Стоимость-привлечения-клиента-CAC" data-toc-modified-id="Стоимость-привлечения-клиента-CAC-6.18"><span class="toc-item-num">6.18&nbsp;&nbsp;</span>Стоимость привлечения клиента CAC</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.19"><span class="toc-item-num">6.19&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Комментарий-от-тимлида" data-toc-modified-id="Комментарий-от-тимлида-6.20"><span class="toc-item-num">6.20&nbsp;&nbsp;</span>Комментарий от тимлида</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Проверка-статистических-гипотез" data-toc-modified-id="Проверка-статистических-гипотез-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Проверка статистических гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-различия-времени-прохождения-уровня" data-toc-modified-id="Гипотеза-различия-времени-прохождения-уровня-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Гипотеза различия времени прохождения уровня</a></span></li><li><span><a href="#Гипотеза-различия-количества-построенных-зданий" data-toc-modified-id="Гипотеза-различия-количества-построенных-зданий-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Гипотеза различия количества построенных зданий</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Вывод</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-тимлида" data-toc-modified-id="Комментарий-от-тимлида-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Комментарий от тимлида</a></span></li><li><span><a href="#Комментарий-от-тимлида-v2" data-toc-modified-id="Комментарий-от-тимлида-v2-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Комментарий от тимлида v2</a></span></li></ul></li><li><span><a href="#Формулирование-модели-монетизации" data-toc-modified-id="Формулирование-модели-монетизации-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Формулирование модели монетизации</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-тимлида-v2" data-toc-modified-id="Комментарий-от-тимлида-v2-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Комментарий от тимлида v2</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><span><a href="#Общий-Комментарий-от-тимлида" data-toc-modified-id="Общий-Комментарий-от-тимлида-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Общий Комментарий от тимлида</a></span></li><li><span><a href="#Общий-Комментарий-от-тимлида-v2" data-toc-modified-id="Общий-Комментарий-от-тимлида-v2-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Общий Комментарий от тимлида v2</a></span></li><li><span><a href="#Общий-Комментарий-от-тимлида-v3" data-toc-modified-id="Общий-Комментарий-от-тимлида-v3-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Общий Комментарий от тимлида v3</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Загрузка данных

# %%
#импортируем библиотеку pandas
import pandas as pd

#импортируем библиотеку numpy
import numpy as np

#импортируем библиотеку stats для работы со статистикой
from scipy import stats as st

#для создания графиков и гистограмм импортируем библиотеку matplotlib
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

#импортируем библиотеку seaborn
import seaborn as sns

#импортируем библиотеку plotly
from plotly import graph_objects as go

import plotly.express as px


#импортируем библиотеку warnings, чтобы скрыть возникающие предупреждения
import warnings
warnings.filterwarnings('ignore')

# %%
#получим общую информацию о таблицах
for item, name in [(game_actions, 'game_actions'), (ad_costs, 'ad_costs'), (user_source, 'user_source')]:
    print('Первые пять строк таблицы', name, ':')
    display(item.head())
    
    print()
    
    print('Общая информация о таблице', name, ':')
    item.info()
    print()
# Out:
# Первые пять строк таблицы game_actions :
#         event_datetime     event  building_type  \
# 0  2020-05-04 00:00:01  building  assembly_shop
# 1  2020-05-04 00:00:03  building  assembly_shop
# 2  2020-05-04 00:00:16  building  assembly_shop
# 3  2020-05-04 00:00:16  building  assembly_shop
# 4  2020-05-04 00:00:35  building  assembly_shop
#
#                                 user_id project_type
# 0  55e92310-cb8e-4754-b622-597e124b03de          NaN
# 1  c07b1c10-f477-44dc-81dc-ec82254b1347          NaN
# 2  6edd42cc-e753-4ff6-a947-2107cd560710          NaN
# 3  92c69003-d60a-444a-827f-8cc51bf6bf4c          NaN
# 4  cdc6bb92-0ccb-4490-9866-ef142f09139d          NaN
# Общая информация о таблице game_actions :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135640 entries, 0 to 135639
# Data columns (total 5 columns):
# event_datetime    135640 non-null object
# event             135640 non-null object
# building_type     127957 non-null object
# user_id           135640 non-null object
# project_type      1866 non-null object
# dtypes: object(5)
# memory usage: 5.2+ MB
#
# Первые пять строк таблицы ad_costs :
#          source         day        cost
# 0  facebook_ads  2020-05-03  935.882786
# 1  facebook_ads  2020-05-04  548.354480
# 2  facebook_ads  2020-05-05  260.185754
# 3  facebook_ads  2020-05-06  177.982200
# 4  facebook_ads  2020-05-07  111.766796
# Общая информация о таблице ad_costs :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
# source    28 non-null object
# day       28 non-null object
# cost      28 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 800.0+ bytes
#
# Первые пять строк таблицы user_source :
#                                 user_id                   source
# 0  0001f83c-c6ac-4621-b7f0-8a28b283ac30             facebook_ads
# 1  00151b4f-ba38-44a8-a650-d7cf130a0105            yandex_direct
# 2  001aaea6-3d14-43f1-8ca8-7f48820f17aa  youtube_channel_reklama
# 3  001d39dc-366c-4021-9604-6a3b9ff01e25    instagram_new_adverts
# 4  002f508f-67b6-479f-814b-b05f00d4e995             facebook_ads
# Общая информация о таблице user_source :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13576 entries, 0 to 13575
# Data columns (total 2 columns):
# user_id    13576 non-null object
# source     13576 non-null object
# dtypes: object(2)
# memory usage: 212.2+ KB

# %% [markdown]
# ## Вывод

# %% [markdown]
# На первом шаге загрузим основной датасет `game_actions.csv` с данными первых пользователей приложения и два дополнительных датасета `ad_costs.csv` и `user_source.csv` с информацией о рекламных активностях.
#
#
# Таблица `game_actions` - данные первых пользователей приложения.
#
#  - Столбцы таблицы `game_actions`:
#
#   - `event_datetime` — время события
#   - `event` — одно из трёх событий:
#     - `building` — объект построен
#     - `finished_stage_1` — первый уровень завершён
#     -  `project` — проект завершён
#
#   - `building_type` — один из трёх типов здания:
#     - `assembly_shop` — сборочный цех
#     - `spaceport` — космопорт
#     - `research_center` — исследовательский центр
#
#   - `user_id` — идентификатор пользователя
#
#   - `project_type` — тип реализованного проекта
#
# В таблице `game_actions` пять столбцов,  количество значений в столбцах отличается: в столбцах `event_datetime`, `event`, `user_id` количество значений одинаковое и составляет 135640, в столбце `building_type` количество значений меньше и составляет
# 127957, в столбце `project_type` значений меньше всего, - 1866. Заменять пропущенные значения не будем, чтобы не испортить общую картину, а рассмотрим датасет как есть.
#
#
# Таблица `ad_costs` - информация о рекламных активностях.
#  - Столбцы таблицы `ad_costs`:
#
#   - `day` - день, в который был совершен клик по объявлению
#   - `source` - источник трафика
#   - `cost` - стоимость кликов
#
#
# В таблице `ad_costs` три столбца, в столбцах `day`, `source`, `cost` количество значений одинаковое и составляет 28.
#
#
# Таблица `user_source` - информация о рекламных активностях.
#  - Столбцы таблицы `user_source`:
#   - `user_id` - идентификатор пользователя
#   - `source` - источников, с которого пришёл пользователь, установивший приложение
#
#
# В таблице `user_source` два столбца, в столбцах `user_id`, `source` количество значений одинаковое и составляет 13576 .
#
# На следующем шаге рассмотрим каждый датасет и каждый столбец отдельно и подготовим данные к исследованию.

# %% [markdown]
# ## Подготовка данных к исследованию

# %%
#посчитаем количество дубликатов в каждой таблице

for item, name in [(game_actions, 'game_actions'), (ad_costs, 'ad_costs'), (user_source, 'user_source')]:
    print('Количество дубликатов в таблице', name, ':', item.duplicated().sum())
# Out:
# Количество дубликатов в таблице game_actions : 1
# Количество дубликатов в таблице ad_costs : 0
# Количество дубликатов в таблице user_source : 0

# %%
#удалим дубликаты в таблице game_actions

game_actions = game_actions.drop_duplicates()

print('Количество дубликатов в таблице game_actions', ':', game_actions.duplicated().sum())
# Out:
# Количество дубликатов в таблице game_actions : 0

# %% [markdown]
# ### Таблица `game_actions` с данными первых пользователей приложения

# %%
# распечатаем таблицу

game_actions.head()
# Out:
#         event_datetime     event  building_type  \
# 0  2020-05-04 00:00:01  building  assembly_shop
# 1  2020-05-04 00:00:03  building  assembly_shop
# 2  2020-05-04 00:00:16  building  assembly_shop
# 3  2020-05-04 00:00:16  building  assembly_shop
# 4  2020-05-04 00:00:35  building  assembly_shop
#
#                                 user_id project_type
# 0  55e92310-cb8e-4754-b622-597e124b03de          NaN
# 1  c07b1c10-f477-44dc-81dc-ec82254b1347          NaN
# 2  6edd42cc-e753-4ff6-a947-2107cd560710          NaN
# 3  92c69003-d60a-444a-827f-8cc51bf6bf4c          NaN
# 4  cdc6bb92-0ccb-4490-9866-ef142f09139d          NaN

# %% [markdown]
# #### Столбец `event_datetime` - время события

# %%
#получим суммарное количество пропусков для столбца

print('Cуммарное количество пропусков для столбца event_datetime:')
print(game_actions['event_datetime'].isnull().sum())
# Out:
# Cуммарное количество пропусков для столбца event_datetime:
# 0

# %%
#выделим уникальные значения в столбце

print('Уникальные значения в столбце event_datetime:')
print(game_actions['event_datetime'].value_counts().head(10))
# Out:
# Уникальные значения в столбце event_datetime:
# 2020-05-10 03:08:18    4
# 2020-05-09 12:35:56    4
# 2020-05-07 17:57:40    4
# 2020-05-08 21:56:19    4
# 2020-05-09 08:39:32    4
# 2020-05-08 22:30:04    4
# 2020-05-04 04:02:30    4
# 2020-05-09 21:49:07    4
# 2020-05-07 03:10:43    4
# 2020-05-10 12:22:52    3
# Name: event_datetime, dtype: int64

# %%
#подсчитаем количество уникальных значений

game_actions['event_datetime'].nunique()
# Out:
# 128790

# %%
#скорректируем формат отображения дат для столбца

game_actions['event_datetime'] = pd.to_datetime(game_actions['event_datetime'], format='%Y-%m-%dT%H:%M:%S')

# %%
game_actions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135639 entries, 0 to 135639
# Data columns (total 5 columns):
# event_datetime    135639 non-null datetime64[ns]
# event             135639 non-null object
# building_type     127956 non-null object
# user_id           135639 non-null object
# project_type      1866 non-null object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 6.2+ MB

# %%
#минимальное значение в столбце

game_actions['event_datetime'].min()
# Out:
# Timestamp('2020-05-04 00:00:01')

# %%
#максимальное значение в столбце

game_actions['event_datetime'].max()
# Out:
# Timestamp('2020-06-05 12:32:49')

# %%
#выделим в отдельные столбцы полную дату и неделю

game_actions['event_date']  = game_actions['event_datetime'].dt.date

game_actions['event_week']  = game_actions['event_datetime'].dt.week

# %%
# первые пять строк таблицы после добавления столбцов

game_actions.head(10)
# Out:
#        event_datetime     event  building_type  \
# 0 2020-05-04 00:00:01  building  assembly_shop
# 1 2020-05-04 00:00:03  building  assembly_shop
# 2 2020-05-04 00:00:16  building  assembly_shop
# 3 2020-05-04 00:00:16  building  assembly_shop
# 4 2020-05-04 00:00:35  building  assembly_shop
# 5 2020-05-04 00:00:36  building  assembly_shop
# 6 2020-05-04 00:00:36  building  assembly_shop
# 7 2020-05-04 00:00:38  building  assembly_shop
# 8 2020-05-04 00:00:44  building  assembly_shop
# 9 2020-05-04 00:01:33  building  assembly_shop
#
#                                 user_id project_type  event_date  event_week
# 0  55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-04          19
# 1  c07b1c10-f477-44dc-81dc-ec82254b1347          NaN  2020-05-04          19
# 2  6edd42cc-e753-4ff6-a947-2107cd560710          NaN  2020-05-04          19
# 3  92c69003-d60a-444a-827f-8cc51bf6bf4c          NaN  2020-05-04          19
# 4  cdc6bb92-0ccb-4490-9866-ef142f09139d          NaN  2020-05-04          19
# 5  06c592ca-902d-42bb-bac3-75ce84cca159          NaN  2020-05-04          19
# 6  4fe0f101-694b-4e31-9740-d1d87f7208ea          NaN  2020-05-04          19
# 7  beb8ca15-33a9-465d-b47b-89aa96f89c9a          NaN  2020-05-04          19
# 8  65a92713-5969-48b1-8945-bfefa5063887          NaN  2020-05-04          19
# 9  fa352362-d258-472c-b295-2796ccc39fa3          NaN  2020-05-04          19

# %% [markdown]
# #### Вывод

# %% [markdown]
# Cуммарное количество пропусков для столбца `event_datetime` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается.
#
# Скорректируем формат отображения дат для столбца и выделим дату в отдельный столбец.
#
# Количество уникальных значений в столбце = 128790.
#
# Период, за который представлены данные в столбце, - с 4 мая по 5 июня 2020 включительно:
#
#  - Максимальное значение даты и времени - 2020-05-04 00:00:01
#  - Максимальное значение даты и времени - 2020-06-05 12:32:49
#
# При этом по условию задачи сказано, что в датасете содержатся данные первых пользователей приложения — когорты пользователей, которые начали пользоваться приложением в период с 4 по 10 мая включительно. Получается, в датасете представлены все действия пользователей, которые скачали приложение и начали играть с 4 по 10 мая и играли до 5 июня.

# %% [markdown]
# #### Столбец `event` - событие

# %%
#получим суммарное количество пропусков для столбца

print('Cуммарное количество пропусков для столбца event:')
print(game_actions['event'].isnull().sum())
# Out:
# Cуммарное количество пропусков для столбца event:
# 0

# %%
#выделим уникальные значения в столбце

print('Уникальные значения в столбце event:')
print(game_actions['event'].value_counts())
# Out:
# Уникальные значения в столбце event:
# building            127956
# finished_stage_1      5817
# project               1866
# Name: event, dtype: int64

# %%
#посмотрим, как распределены уникальные пользователи

event_user_id = game_actions.groupby('event').agg({'user_id':'nunique'}).reset_index().sort_values(by = 'user_id', ascending = False)
event_user_id
# Out:
#               event  user_id
# 0          building    13576
# 1  finished_stage_1     5817
# 2           project     1866

# %%
#подсчитаем % завершивших первый уровень

print('Процент завершивших первый уровень: {:.2%}'.format(event_user_id['user_id'].loc[1]/event_user_id['user_id'].loc[0]))
# Out:
# Процент завершивших первый уровень: 42.85%

# %%
#построим график распределения уникальных пользователей

plt.figure(figsize=(15,7))
ax = sns.barplot(data=event_user_id, x='event', y='user_id')
plt.suptitle('Распределение уникальных пользователей по типам событий')
plt.xlabel('Событие')
plt.ylabel('Количество уникальных пользователей')
sns.set_palette('dark') 

#добавим подписи

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.0f}'.format(height),
            ha="center")

# %% [markdown]
# #### Вывод

# %% [markdown]
# Cуммарное количество пропусков для столбца `event` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
# Посмотрим, как распределены данные по событиям:
#
#  - building (объект построен) = 127956 значений
#  - finished_stage_1 (первый уровень завершён) = 5817 значений
#  - project (проект завершён) = 1866 значений
#
# Также посмотрим, как распределены уникальные пользователи по событиям:
#
#  - building (объект построен) = 13576 пользователей
#  - finished_stage_1 (первый уровень завершён) = 5817 пользователей
#  - project (проект завершён) = 1866 пользователей
#
#
# По условию задачи в датасете представлены данные по игре пользователей на первом уровне, и завершение первого уровня требует от игрока выполнения одного из двух условий:
#
# - Победа над первым врагом
# - Реализация проекта - разработка орбитальной сборки спутников
#
# Целевое событие - завершение первого уровня. Таким образом, первый уровень завершён у 5817 пользователей. Процент завершивших первый уровень составляет 42.85%.
# Из них 1866 пользователей завершили уровень через реализацию проекта (разработку орбитальной сборки спутников). А 5817 - 1866  = 3951 завершили уровень через победу над первым врагом. Т.е. способ прохождения уровня через победу над врагом пользователи предпочитают больше, чем разработку орбитальной сборки спутников.

# %% [markdown]
# #### Столбец `building_type` - тип здания

# %%
#получим суммарное количество пропусков для столбца

print('Cуммарное количество пропусков для столбца building_type:')
print(game_actions['building_type'].isnull().sum())
# Out:
# Cуммарное количество пропусков для столбца building_type:
# 7683

# %%
#выделим уникальные значения в столбце

print('Уникальные значения в столбце building_type:')
print(game_actions['building_type'].value_counts())
# Out:
# Уникальные значения в столбце building_type:
# spaceport          59325
# assembly_shop      54494
# research_center    14137
# Name: building_type, dtype: int64

# %%
#посмотрим, как распределены уникальные пользователи

building_type_user_id = game_actions.groupby('building_type').agg({'user_id':'nunique'}).reset_index().sort_values(by = 'user_id', ascending = False)
building_type_user_id
# Out:
#      building_type  user_id
# 0    assembly_shop    13576
# 2        spaceport    13231
# 1  research_center     7671

# %%
#построим график распределения уникальных пользователей

plt.figure(figsize=(15,7))
ax = sns.barplot(data= building_type_user_id, x='building_type', y='user_id')
plt.suptitle('Распределение уникальных пользователей по типам зданий')
plt.xlabel('Событие')
plt.ylabel('Количество уникальных пользователей')
sns.set_palette('dark') 

#добавим подписи

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.0f}'.format(height),
            ha="center")

# %% [markdown]
# #### Вывод

# %% [markdown]
# Суммарное количество пропусков для столбца `building_type` равно 7683.
#
# Корректировки вносить не будем. Тип данных не меняем.
#
# Посмотрим, как распределены данные по типам зданий:
#
#  - spaceport (космопорт) = 59325 значений
#  - assembly_shop (сборочный цех) = 54494 значения
#  - research_center (исследовательский центр) = 14137 значений
#
#
# Также посмотрим, как распределены уникальные пользователи по типам зданий:
#
#  - spaceport (космопорт) = 13576 пользователей
#  - assembly_shop (сборочный цех) = 13231 пользователь
#  - research_center (исследовательский центр) = 7671 пользователь

# %% [markdown]
# #### Столбец `user_id` - идентификатор пользователя

# %%
#получим суммарное количество пропусков для столбца

print('Cуммарное количество пропусков для столбца user_id:')
print(game_actions['user_id'].isnull().sum())
# Out:
# Cуммарное количество пропусков для столбца user_id:
# 0

# %%
#выделим уникальные значения в столбце

print('Уникальные значения в столбце user_id:')
print(game_actions['user_id'].value_counts().head(10))
# Out:
# Уникальные значения в столбце user_id:
# ff841992-d93b-462e-bc6e-18c24a514f36    22
# bf542075-e3a2-4e79-82d8-3838e86d2a25    22
# d6aca06a-cd75-4cd8-b8cd-240a3c163884    22
# 296c14d6-34a8-4cc9-8b87-80c089e3ebdb    21
# 3e5208a6-e373-4246-b2f5-a8a5ee2350f1    21
# c133dd1d-c5d0-48e8-aaf7-f654be5b9b56    21
# fa36cf08-cda1-4ee3-bee9-be16ded7071e    21
# 94844e06-0352-4048-9e62-1db7718f804c    21
# 4f57b9dc-faa4-4ced-8c6f-1098d612438c    21
# 45935e5d-8f50-4176-83d3-fd545bb2015f    21
# Name: user_id, dtype: int64

# %%
#подсчитаем количество уникальных пользователей

game_actions['user_id'].nunique()
# Out:
# 13576

# %% [markdown]
# #### Вывод

# %% [markdown]
# Cуммарное количество пропусков для столбца `user_id` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
# Количество уникальных пользователей - 13576.

# %% [markdown]
# #### Столбец `project_type` - тип реализованного проекта

# %%
#получим суммарное количество пропусков для столбца

print('Cуммарное количество пропусков для столбца project_type:')
print(game_actions['project_type'].isnull().sum())
# Out:
# Cуммарное количество пропусков для столбца project_type:
# 133773

# %%
#выделим уникальные значения в столбце

print('Уникальные значения в столбце project_type:')
print(game_actions['project_type'].value_counts())
# Out:
# Уникальные значения в столбце project_type:
# satellite_orbital_assembly    1866
# Name: project_type, dtype: int64

# %% [markdown]
# #### Вывод

# %% [markdown]
# Cуммарное количество пропусков для столбца `project_type` равно 133773.
#
# Корректировки вносить не будем. Тип данных не меняем.
#
# В столбце представлен только один тип реализованного объекта:
#
#  - satellite_orbital_assembly (разработка орбитальной сборки спутников) = 1866

# %% [markdown]
# ### Таблица `ad_costs` с информацией о рекламных активностях

# %%
# распечатаем таблицу с расходами

ad_costs.head()
# Out:
#          source         day        cost
# 0  facebook_ads  2020-05-03  935.882786
# 1  facebook_ads  2020-05-04  548.354480
# 2  facebook_ads  2020-05-05  260.185754
# 3  facebook_ads  2020-05-06  177.982200
# 4  facebook_ads  2020-05-07  111.766796

# %% [markdown]
# #### Столбец `source` - источник трафика

# %%
#получим суммарное количество пропусков для столбца

print('Cуммарное количество пропусков для столбца source:')
print(ad_costs['source'].isnull().sum())
# Out:
# Cуммарное количество пропусков для столбца source:
# 0

# %%
#выделим уникальные значения в столбце

print('Уникальные значения в столбце source:')
print(ad_costs['source'].value_counts())
# Out:
# Уникальные значения в столбце source:
# yandex_direct              7
# youtube_channel_reklama    7
# facebook_ads               7
# instagram_new_adverts      7
# Name: source, dtype: int64

# %% [markdown]
# #### Вывод

# %% [markdown]
# Cуммарное количество пропусков для столбца `source` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается.
#
# Корректировки вносить не будем. Тип данных не меняем.
#
# Уникальные источники трафика:
#
#  - yandex_direct = 7
#  - instagram_new_adverts = 7
#  - youtube_channel_reklama = 7
#  - facebook_ads = 7

# %% [markdown]
# #### Столбец `day` - день, в который был совершен клик по объявлению

# %%
#получим суммарное количество пропусков для столбца

print('Cуммарное количество пропусков для столбца day:')
print(ad_costs['day'].isnull().sum())
# Out:
# Cуммарное количество пропусков для столбца day:
# 0

# %%
#выделим уникальные значения в столбце

print('Уникальные значения в столбце day:')
print(ad_costs['day'].value_counts())
# Out:
# Уникальные значения в столбце day:
# 2020-05-09    4
# 2020-05-05    4
# 2020-05-06    4
# 2020-05-03    4
# 2020-05-08    4
# 2020-05-07    4
# 2020-05-04    4
# Name: day, dtype: int64

# %%
#скорректируем формат отображения дат для столбца

ad_costs['day'] = pd.to_datetime(ad_costs['day'], format='%Y-%m-%d')

# %%
# найдём минимальное значение в столбце

ad_costs['day'].min()
# Out:
# Timestamp('2020-05-03 00:00:00')

# %%
# найдём максимальное значение в столбце

ad_costs['day'].max()
# Out:
# Timestamp('2020-05-09 00:00:00')

# %% [markdown]
# #### Вывод

# %% [markdown]
# Cуммарное количество пропусков для столбца `day` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается.
#
# Скорректируем формат отображения дат для столбца.
#
# Количество уникальных значений в столбце = 7.
#
# Период, за который представлены данные в столбце, - с 3 мая по 9 мая 2020 включительно:
#
#  - Максимальное значение даты и времени - 2020-05-03
#  - Максимальное значение даты и времени - 2020-05-09

# %% [markdown]
# #### Столбец `cost` - стоимость кликов

# %%
#получим суммарное количество пропусков для столбца

print('Cуммарное количество пропусков для столбца cost:')
print(ad_costs['cost'].isnull().sum())
# Out:
# Cуммарное количество пропусков для столбца cost:
# 0

# %%
#получим числовое описание данных (список характерных значений) для столбца

print(ad_costs['cost'].describe())
# Out:
# count     28.000000
# mean     271.556321
# std      286.867650
# min       23.314669
# 25%       66.747365
# 50%      160.056443
# 75%      349.034473
# max      969.139394
# Name: cost, dtype: float64

# %%
#построим гистограмму

ad_costs.hist('cost', figsize=(15,7), bins = 'auto')
plt.suptitle('Гистограмма для параметра "Стоимость кликов"')
plt.xlabel('Стоимость кликов')
plt.show()

# %%
#построим диаграмму размаха или "ящик с усами" 

ad_costs['cost'].plot.box(grid=True, title='Диаграмма размаха для параметра "Стоимость кликов"', figsize=(15,7))
plt.xlabel('Стоимость кликов')
plt.show()

# %%
#посмотрим, как распределена стоимость по источникам трафика

source_cost = ad_costs.groupby('source').agg({'cost':'sum'}).reset_index().sort_values(by = 'cost', ascending = False)
source_cost
# Out:
#                     source         cost
# 2            yandex_direct  2233.111449
# 1    instagram_new_adverts  2161.441691
# 0             facebook_ads  2140.904643
# 3  youtube_channel_reklama  1068.119204

# %%
#построим график распределения стоимости по источникам трафика

plt.figure(figsize=(15,7))
ax = sns.barplot(data= source_cost, x='source', y='cost')
plt.suptitle('Распределение стоимости по источникам трафика')
plt.xlabel('Источник трафика')
plt.ylabel('Суммарная стоимость')
sns.set_palette('dark') 

#добавим подписи

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 50,
            '{:1.2f}'.format(height),
            ha="center")

# %% [markdown]
# #### Вывод

# %% [markdown]
# Cуммарное количество пропусков для столбца `cost` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается.
#
# Количество уникальных значений в столбце = 28.
#
#  - Максимальная стоимость кликов =  969.13
#  - Минимальная стоимость кликов = 23.31
#  - Среднее значение стоимости кликов = 271.55
#  - Медианное значение стоимости кликов = 160.05
#
# На гистограмме распределение не похоже на нормальное, на диаграмме размаха отображаются выбросы. Ориентироваться будем на медианное значение.
#
# Распределение стоимости кликов по источникам трафика:
#  - yandex_direct =  2233.11
#  - instagram_new_adverts = 2161.44
#  - facebook_ads	 = 2140.90
#  - youtube_channel_reklama = 1068.11
#
# Таким образом, самая большая суммарная стоимость кликов приходится на источник трафика yandex_direct, на втором месте instagram_new_adverts, на третьем месте facebook_ads, а меньше всего  - на  youtube_channel_reklama.

# %% [markdown]
# ### Таблица `user_source` с информацией о рекламных активностях

# %%
# распечатаем таблицу

user_source.head()
# Out:
#                                 user_id                   source
# 0  0001f83c-c6ac-4621-b7f0-8a28b283ac30             facebook_ads
# 1  00151b4f-ba38-44a8-a650-d7cf130a0105            yandex_direct
# 2  001aaea6-3d14-43f1-8ca8-7f48820f17aa  youtube_channel_reklama
# 3  001d39dc-366c-4021-9604-6a3b9ff01e25    instagram_new_adverts
# 4  002f508f-67b6-479f-814b-b05f00d4e995             facebook_ads

# %% [markdown]
# #### Столбец `user_id` - идентификатор пользователя

# %%
#получим суммарное количество пропусков для столбца

print('Cуммарное количество пропусков для столбца user_id:')
print(user_source['user_id'].isnull().sum())
# Out:
# Cуммарное количество пропусков для столбца user_id:
# 0

# %%
#выделим уникальные значения в столбце

print('Уникальные значения в столбце user_id:')
print(user_source['user_id'].value_counts().head(10))
# Out:
# Уникальные значения в столбце user_id:
# 5ccbced7-9967-4eac-b2e4-033eff6fc37d    1
# 7f9f7abb-6610-4a4d-9fc6-27ad5d1f631f    1
# 1e98ce8f-b056-4055-937f-f0678001faaf    1
# 85b7e139-58ba-4318-be84-bd40f83271f3    1
# 76ace0cb-d62b-4e48-8e58-d49983cc17ff    1
# 488d9cb7-cd34-4c62-89fc-7dee85254d94    1
# 7e59d584-eb5e-44af-bb9e-58dc24128479    1
# b132b82a-3e91-41a1-ae5c-3e1bc61b867f    1
# 1fc6d616-22d4-4f58-a2b4-7228a75c2d64    1
# 3f147f62-2ec3-471e-9d69-b7ed3a7f0bbb    1
# Name: user_id, dtype: int64

# %%
#подсчитаем количество уникальных пользователей

user_source['user_id'].nunique()
# Out:
# 13576

# %% [markdown]
# #### Вывод

# %% [markdown]
# Cуммарное количество пропусков для столбца `user_id` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
# Количество уникальных пользователей - 13576.

# %% [markdown]
# #### Столбец `source` - источник, с которого пришёл пользователь, установивший приложение

# %%
#получим суммарное количество пропусков для столбца

print('Cуммарное количество пропусков для столбца source:')
print(user_source['source'].isnull().sum())
# Out:
# Cуммарное количество пропусков для столбца source:
# 0

# %%
#выделим уникальные значения в столбце

print('Уникальные значения в столбце source:')
print(user_source['source'].value_counts())
# Out:
# Уникальные значения в столбце source:
# yandex_direct              4817
# instagram_new_adverts      3347
# facebook_ads               2726
# youtube_channel_reklama    2686
# Name: source, dtype: int64

# %%
#посмотрим, как распределены уникальные пользователи

source_user_id = user_source.groupby('source').agg({'user_id':'nunique'}).reset_index().sort_values(by = 'user_id', ascending = False)
source_user_id
# Out:
#                     source  user_id
# 2            yandex_direct     4817
# 1    instagram_new_adverts     3347
# 0             facebook_ads     2726
# 3  youtube_channel_reklama     2686

# %%
#построим график распределения стоимости по источникам трафика

plt.figure(figsize=(15,7))
ax = sns.barplot(data= source_user_id, x='source', y='user_id')
plt.suptitle('Распределение уникальных пользователей по источникам трафика')
plt.xlabel('Источник трафика')
plt.ylabel('Количество уникальных пользователей')
sns.set_palette('dark') 

#добавим подписи

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 50,
            '{:1.0f}'.format(height),
            ha="center")

# %% [markdown]
# #### Вывод

# %% [markdown]
# Cуммарное количество пропусков для столбца `source` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
# Распределение уникальных пользователей по источникам трафика:
#
#  - yandex_direct =  4817 пользователей
#  - instagram_new_adverts = 3347 пользователей
#  - facebook_ads	 = 2726 пользователей
#  - youtube_channel_reklama = 2686 пользователей
#
# Аналогично распределению стоимости кликов, больше всего пользователей приходится на источник трафика yandex_direct, на втором месте instagram_new_adverts, на третьем месте facebook_ads, а меньше всего  - на  youtube_channel_reklama.

# %% [markdown]
# ## Вывод

# %% [markdown]
# На данном шаге рассмотрим каждый датасет и каждый столбец отдельно и подготовим данные к исследованию.
#
# Проверим на наличие дубликатов каждый датасет. Количество дубликатов в таблице `game_actions` составляет 1, исключим данный дубликат. Количество дубликатов в таблицах `ad_costs.csv` и `user_source.csv` равно нулю.
#
#
# <b>Таблица `game_actions`:</b>
#
#  - Столбец `event_datetime` - время события
#
#   - Cуммарное количество пропусков для столбца `event_datetime` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Скорректируем формат отображения дат для столбца и выделим дату в отдельный столбец.
#   - Период, за который представлены данные в столбце, - с 4 мая по 5 июня включительно:
#     - Максимальное значение даты и времени - 2020-05-04 00:00:01
#     - Максимальное значение даты и времени - 2020-06-05 12:32:49
#     - При этом по условию задачи сказано, что в датасете содержатся данные первых пользователей приложения — когорты пользователей, которые начали пользоваться приложением в период с 4 по 10 мая включительно.
#
#
#  - Столбец `event` - событие
#
#   - Cуммарное количество пропусков для столбца `event` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
#   - Посмотрим, как распределены данные по событиям:
#     - building (объект построен) = 127956 значений
#     - finished_stage_1 (первый уровень завершён) = 5817 значений
#     - project (проект завершён) = 1866 значений
#
#   - Также посмотрим, как распределены уникальные пользователи по событиям:
#     - building (объект построен) = 13576 пользователей
#     - finished_stage_1 (первый уровень завершён) = 5817 пользователей
#     - project (проект завершён) = 1866 пользователей
#
#   - По условию задачи в датасете представлены данные по игре пользователей на первом уровне, и завершение первого уровня требует от игрока выполнения одного из двух условий:
#       - Победа над первым врагом
#       - Реализация проекта - разработка орбитальной сборки спутников
#
#   - Целевое событие - завершение первого уровня. Таким образом, первый уровень завершён finished_stage_1 у 5817 пользователей. Процент завершивших первый уровень составляет 42.85%. Из них 1866 пользователей завершили уровень через реализацию проекта project (разработку орбитальной сборки спутников). А 5817 - 1866  = 3951 завершили уровень через победу над первым врагом. Т.е. способ прохождения уровня через победу над врагом пользователи предпочитают больше, чем разработку орбитальной сборки спутников.
#
#
#  - Столбец `building_type` - тип здания
#
#   - Суммарное количество пропусков для столбца `building_type` равно 7683. Корректировки вносить не будем. Тип данных не меняем.
#
#   - Посмотрим, как распределены данные по типам зданий:
#     - spaceport (космопорт) = 59325 значений
#     - assembly_shop (сборочный цех) = 54494 значения
#     - research_center (исследовательский центр) = 14137 значений
#
#   - Также посмотрим, как распределены уникальные пользователи по типам зданий:
#     - spaceport (космопорт) = 13576 пользователей
#     - assembly_shop (сборочный цех) = 13231 пользователь
#     - research_center (исследовательский центр) = 7671 пользователь
#
#
#  - Столбец `user_id` - идентификатор пользователя
#
#   - Cуммарное количество пропусков для столбца `user_id` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#   - Количество уникальных пользователей - 13576.
#
#
#  - Столбец `project_type` - тип реализованного проекта
#
#   - Cуммарное количество пропусков для столбца `project_type` равно 133773. Корректировки вносить не будем. Тип данных не меняем.
#
#   - В столбце представлен только один тип реализованного объекта:
#     - satellite_orbital_assembly (разработка орбитальной сборки спутников) = 1866
#
#
#
# <b>Таблица `game_actions`:</b>
#
#
#  - Столбец `source` - источник трафика
#
#   - Cуммарное количество пропусков для столбца `source` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
#   - Уникальные источники трафика:
#     - yandex_direct = 7
#     - instagram_new_adverts = 7
#     - youtube_channel_reklama = 7
#     - facebook_ads = 7
#
#
#  - Столбец `day` - день, в который был совершен клик по объявлению
#
#   - Cуммарное количество пропусков для столбца `day` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Скорректируем формат отображения дат для столбца.
#   - Количество уникальных значений в столбце = 7.
#
#   - Период, за который представлены данные в столбце, - с 3 мая по 9 мая 2020 включительно:
#     - Максимальное значение даты и времени - 2020-05-03
#     - Максимальное значение даты и времени - 2020-05-09
#
#  - Столбец `cost` - стоимость кликов
#
#   - Cуммарное количество пропусков для столбца `cost` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается.
#
#     - Максимальная стоимость кликов =  969.13
#     - Минимальная стоимость кликов = 23.31
#     - Среднее значение стоимости кликов = 271.55
#     - Медианное значение стоимости кликов = 160.05
#
#   - На гистограмме распределение не похоже на нормальное, на диаграмме размаха отображаются выбросы. Ориентироваться будем на медианное значение.
#
#   - Распределение стоимости кликов по источникам трафика:
#      - yandex_direct =  2233.11
#      - instagram_new_adverts = 2161.44
#      - facebook_ads	 = 2140.90
#      - youtube_channel_reklama = 1068.11
#
#  - Таким образом, самая большая суммарная стоимость кликов приходится на источник трафика yandex_direct, на втором месте instagram_new_adverts, на третьем месте facebook_ads, а меньше всего  - на  youtube_channel_reklama.
#
#
#
#
#
# <b>Таблица `user_source`:</b>
#
#  - Столбец `user_id` - идентификатор пользователя
#
#   - Cуммарное количество пропусков для столбца `user_id` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
#   - Количество уникальных пользователей - 13576.
#
#
#  - Столбец `source` - источник, с которого пришёл пользователь, установивший приложение
#
#  - Cуммарное количество пропусков для столбца `source` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
#  - Распределение уникальных пользователей по источникам трафика:
#
#    - yandex_direct =  4817 пользователей
#    - instagram_new_adverts = 3347 пользователей
#    - facebook_ads	 = 2726 пользователей
#    - youtube_channel_reklama = 2686 пользователей
#  - Аналогично распределению стоимости кликов, больше всего пользователей приходится на источник трафика yandex_direct, на втором месте instagram_new_adverts, на третьем месте facebook_ads, а меньше всего  - на  youtube_channel_reklama.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Среднее время прохождения уровня

# %%
# отберём пользователей, которые завершили уровень через реализацию проекта

user_project = game_actions.query('event == "project"')
user_project.head()
# Out:
#            event_datetime    event building_type  \
# 47121 2020-05-08 18:10:25  project           NaN
# 57398 2020-05-09 13:49:11  project           NaN
# 58797 2020-05-09 16:19:33  project           NaN
# 61174 2020-05-09 20:29:01  project           NaN
# 63770 2020-05-10 00:57:47  project           NaN
#
#                                     user_id                project_type  \
# 47121  e3c66498-9d45-4000-9392-f81e6796e7da  satellite_orbital_assembly
# 57398  936e7af6-8338-4703-a1df-fc6c3f5b8e34  satellite_orbital_assembly
# 58797  a4491c86-c498-4f74-a56e-65c136d0e9a1  satellite_orbital_assembly
# 61174  85d9e675-562b-4329-8bbd-14d3b39096be  satellite_orbital_assembly
# 63770  1889ca71-3c57-4e61-9ea6-a711971bbf0a  satellite_orbital_assembly
#
#        event_date  event_week
# 47121  2020-05-08          19
# 57398  2020-05-09          19
# 58797  2020-05-09          19
# 61174  2020-05-09          19
# 63770  2020-05-10          19

# %%
#создадим список пользователей, которые прошли уровень через реализацию проекта

user_project = user_project['user_id']
user_project.head()
# Out:
# 47121    e3c66498-9d45-4000-9392-f81e6796e7da
# 57398    936e7af6-8338-4703-a1df-fc6c3f5b8e34
# 58797    a4491c86-c498-4f74-a56e-65c136d0e9a1
# 61174    85d9e675-562b-4329-8bbd-14d3b39096be
# 63770    1889ca71-3c57-4e61-9ea6-a711971bbf0a
# Name: user_id, dtype: object

# %%
#создадим новый столбец с вариантом прохождения уровня "Реализация проекта"

game_actions.loc[game_actions['event'] == "project", 'type'] = 'Реализация проекта'

game_actions.head()
# Out:
#        event_datetime     event  building_type  \
# 0 2020-05-04 00:00:01  building  assembly_shop
# 1 2020-05-04 00:00:03  building  assembly_shop
# 2 2020-05-04 00:00:16  building  assembly_shop
# 3 2020-05-04 00:00:16  building  assembly_shop
# 4 2020-05-04 00:00:35  building  assembly_shop
#
#                                 user_id project_type  event_date  event_week  \
# 0  55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-04          19
# 1  c07b1c10-f477-44dc-81dc-ec82254b1347          NaN  2020-05-04          19
# 2  6edd42cc-e753-4ff6-a947-2107cd560710          NaN  2020-05-04          19
# 3  92c69003-d60a-444a-827f-8cc51bf6bf4c          NaN  2020-05-04          19
# 4  cdc6bb92-0ccb-4490-9866-ef142f09139d          NaN  2020-05-04          19
#
#   type
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
#добавим в новый столбец вариант прохождения уровня "Победа над первым врагом"

game_actions.loc[(game_actions['event'] == "finished_stage_1") 
                  & (~game_actions['user_id'].isin(user_project)), 'type'] = 'Победа над первым врагом'
                     
game_actions.head()
# Out:
#        event_datetime     event  building_type  \
# 0 2020-05-04 00:00:01  building  assembly_shop
# 1 2020-05-04 00:00:03  building  assembly_shop
# 2 2020-05-04 00:00:16  building  assembly_shop
# 3 2020-05-04 00:00:16  building  assembly_shop
# 4 2020-05-04 00:00:35  building  assembly_shop
#
#                                 user_id project_type  event_date  event_week  \
# 0  55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-04          19
# 1  c07b1c10-f477-44dc-81dc-ec82254b1347          NaN  2020-05-04          19
# 2  6edd42cc-e753-4ff6-a947-2107cd560710          NaN  2020-05-04          19
# 3  92c69003-d60a-444a-827f-8cc51bf6bf4c          NaN  2020-05-04          19
# 4  cdc6bb92-0ccb-4490-9866-ef142f09139d          NaN  2020-05-04          19
#
#   type
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
#посмотрим, как распределены уникальные пользователи

type_event = game_actions.groupby('type').agg({'user_id':'nunique'}).reset_index().sort_values(by = 'user_id', ascending = False)
type_event['%'] = type_event['user_id'] / game_actions['user_id'].nunique() * 100
type_event
# Out:
#                        type  user_id          %
# 0  Победа над первым врагом     3951  29.102829
# 1        Реализация проекта     1866  13.744844

# %%
#отберем победителей и подсчитаем минимальную дату победы для каждого пользователя

win_game_date = game_actions.query('type == type').groupby('user_id').agg({'event_datetime':'min', 'type':'min'}).rename(columns = {'event_datetime': 'win_game_date'})
win_game_date
# Out:
#                                            win_game_date  \
# user_id
# 001d39dc-366c-4021-9604-6a3b9ff01e25 2020-05-12 07:40:47
# 003ee7e8-6356-4286-a715-62f22a18d2a1 2020-05-17 21:47:49
# 004074f8-251a-4776-922c-8348dca1a2f6 2020-05-16 19:57:40
# 00464e5e-28ed-4be6-bf44-517ef7b3937b 2020-05-15 16:02:01
# 0056c007-c082-43cc-bdef-afc49bca4cb9 2020-05-16 13:48:39
# ...                                                  ...
# ffd002f3-3545-423e-8dba-0c6a2d48a3aa 2020-05-19 04:03:24
# ffe810f4-1a1f-464b-924d-6f120b0cb8df 2020-05-18 02:03:36
# ffef4fed-164c-40e1-bde1-3980f76d0fb5 2020-05-11 22:15:54
# fffb626c-5ab6-47c9-8113-2062a2f18494 2020-05-12 13:01:52
# ffff69cc-fec1-4fd3-9f98-93be1112a6b8 2020-05-25 03:55:06
#
#                                                           type
# user_id
# 001d39dc-366c-4021-9604-6a3b9ff01e25  Победа над первым врагом
# 003ee7e8-6356-4286-a715-62f22a18d2a1  Победа над первым врагом
# 004074f8-251a-4776-922c-8348dca1a2f6  Победа над первым врагом
# 00464e5e-28ed-4be6-bf44-517ef7b3937b  Победа над первым врагом
# 0056c007-c082-43cc-bdef-afc49bca4cb9  Победа над первым врагом
# ...                                                        ...
# ffd002f3-3545-423e-8dba-0c6a2d48a3aa  Победа над первым врагом
# ffe810f4-1a1f-464b-924d-6f120b0cb8df  Победа над первым врагом
# ffef4fed-164c-40e1-bde1-3980f76d0fb5  Победа над первым врагом
# fffb626c-5ab6-47c9-8113-2062a2f18494  Победа над первым врагом
# ffff69cc-fec1-4fd3-9f98-93be1112a6b8        Реализация проекта
#
# [5817 rows x 2 columns]

# %%
#подсчитаем минимальную дату для каждого пользователя

start_game_date = game_actions.groupby('user_id').agg({'event_datetime':'min'}).rename(columns = {'event_datetime': 'start_game_date'})
start_game_date
# Out:
#                                          start_game_date
# user_id
# 0001f83c-c6ac-4621-b7f0-8a28b283ac30 2020-05-06 01:07:37
# 00151b4f-ba38-44a8-a650-d7cf130a0105 2020-05-06 03:09:12
# 001aaea6-3d14-43f1-8ca8-7f48820f17aa 2020-05-05 18:08:52
# 001d39dc-366c-4021-9604-6a3b9ff01e25 2020-05-05 21:02:05
# 002f508f-67b6-479f-814b-b05f00d4e995 2020-05-05 13:49:58
# ...                                                  ...
# ffef4fed-164c-40e1-bde1-3980f76d0fb5 2020-05-04 01:58:59
# fffab3da-da0e-4e30-ae62-10d0a2e24a4e 2020-05-04 11:58:14
# fffb626c-5ab6-47c9-8113-2062a2f18494 2020-05-04 02:05:09
# ffff194a-56b7-4c12-860d-3485242ae7f5 2020-05-04 20:28:28
# ffff69cc-fec1-4fd3-9f98-93be1112a6b8 2020-05-08 06:57:30
#
# [13576 rows x 1 columns]

# %%
#объединим win_game_date и start_game_date

merge_game = win_game_date.merge(start_game_date, how='inner', on = 'user_id').reset_index()
merge_game
# Out:
#                                    user_id       win_game_date  \
# 0     001d39dc-366c-4021-9604-6a3b9ff01e25 2020-05-12 07:40:47
# 1     003ee7e8-6356-4286-a715-62f22a18d2a1 2020-05-17 21:47:49
# 2     004074f8-251a-4776-922c-8348dca1a2f6 2020-05-16 19:57:40
# 3     00464e5e-28ed-4be6-bf44-517ef7b3937b 2020-05-15 16:02:01
# 4     0056c007-c082-43cc-bdef-afc49bca4cb9 2020-05-16 13:48:39
# ...                                    ...                 ...
# 5812  ffd002f3-3545-423e-8dba-0c6a2d48a3aa 2020-05-19 04:03:24
# 5813  ffe810f4-1a1f-464b-924d-6f120b0cb8df 2020-05-18 02:03:36
# 5814  ffef4fed-164c-40e1-bde1-3980f76d0fb5 2020-05-11 22:15:54
# 5815  fffb626c-5ab6-47c9-8113-2062a2f18494 2020-05-12 13:01:52
# 5816  ffff69cc-fec1-4fd3-9f98-93be1112a6b8 2020-05-25 03:55:06
#
#                           type     start_game_date
# 0     Победа над первым врагом 2020-05-05 21:02:05
# 1     Победа над первым врагом 2020-05-05 08:31:04
# 2     Победа над первым врагом 2020-05-04 01:07:35
# 3     Победа над первым врагом 2020-05-04 08:35:29
# 4     Победа над первым врагом 2020-05-10 11:49:47
# ...                        ...                 ...
# 5812  Победа над первым врагом 2020-05-06 06:34:18
# 5813  Победа над первым врагом 2020-05-04 17:46:05
# 5814  Победа над первым врагом 2020-05-04 01:58:59
# 5815  Победа над первым врагом 2020-05-04 02:05:09
# 5816        Реализация проекта 2020-05-08 06:57:30
#
# [5817 rows x 4 columns]

# %%
#подсчитаем время прохождения уровня

merge_game['game_time'] = merge_game['win_game_date'] - merge_game['start_game_date']
merge_game
# Out:
#                                    user_id       win_game_date  \
# 0     001d39dc-366c-4021-9604-6a3b9ff01e25 2020-05-12 07:40:47
# 1     003ee7e8-6356-4286-a715-62f22a18d2a1 2020-05-17 21:47:49
# 2     004074f8-251a-4776-922c-8348dca1a2f6 2020-05-16 19:57:40
# 3     00464e5e-28ed-4be6-bf44-517ef7b3937b 2020-05-15 16:02:01
# 4     0056c007-c082-43cc-bdef-afc49bca4cb9 2020-05-16 13:48:39
# ...                                    ...                 ...
# 5812  ffd002f3-3545-423e-8dba-0c6a2d48a3aa 2020-05-19 04:03:24
# 5813  ffe810f4-1a1f-464b-924d-6f120b0cb8df 2020-05-18 02:03:36
# 5814  ffef4fed-164c-40e1-bde1-3980f76d0fb5 2020-05-11 22:15:54
# 5815  fffb626c-5ab6-47c9-8113-2062a2f18494 2020-05-12 13:01:52
# 5816  ffff69cc-fec1-4fd3-9f98-93be1112a6b8 2020-05-25 03:55:06
#
#                           type     start_game_date        game_time
# 0     Победа над первым врагом 2020-05-05 21:02:05  6 days 10:38:42
# 1     Победа над первым врагом 2020-05-05 08:31:04 12 days 13:16:45
# 2     Победа над первым врагом 2020-05-04 01:07:35 12 days 18:50:05
# 3     Победа над первым врагом 2020-05-04 08:35:29 11 days 07:26:32
# 4     Победа над первым врагом 2020-05-10 11:49:47  6 days 01:58:52
# ...                        ...                 ...              ...
# 5812  Победа над первым врагом 2020-05-06 06:34:18 12 days 21:29:06
# 5813  Победа над первым врагом 2020-05-04 17:46:05 13 days 08:17:31
# 5814  Победа над первым врагом 2020-05-04 01:58:59  7 days 20:16:55
# 5815  Победа над первым врагом 2020-05-04 02:05:09  8 days 10:56:43
# 5816        Реализация проекта 2020-05-08 06:57:30 16 days 20:57:36
#
# [5817 rows x 5 columns]

# %%
#подсчитаем среднее время прохождения уровня

print('Среднее время прохождения уровня для обоих вариантов:',
      merge_game['game_time'].mean())
# Out:
# Среднее время прохождения уровня для обоих вариантов: 11 days 08:31:30.522262

# %%
#подсчитаем медианное время прохождения уровня

print('Медианное время прохождения уровня для обоих вариантов:',
      merge_game['game_time'].median())
# Out:
# Медианное время прохождения уровня для обоих вариантов: 10 days 23:42:56

# %%
#подсчитаем среднее время прохождения уровня для варианта победы над первым врагом

print('Среднее время прохождения уровня для варианта "Победа над первым врагом":',
      merge_game.query('type == "Победа над первым врагом"')['game_time'].mean())
# Out:
# Среднее время прохождения уровня для варианта "Победа над первым врагом": 11 days 02:30:24.076183

# %%
#подсчитаем медианное время прохождения уровня для варианта победы над первым врагом

print('Медианное время прохождения уровня для варианта "Победа над первым врагом":',
      merge_game.query('type == "Победа над первым врагом"')['game_time'].median())
# Out:
# Медианное время прохождения уровня для варианта "Победа над первым врагом": 10 days 19:01:37

# %%
#подсчитаем среднее время прохождения уровня для варианта реализации проекта

print('Среднее время прохождения уровня для варианта "Реализация проекта":',
      merge_game.query('type == "Реализация проекта"')['game_time'].mean())
# Out:
# Среднее время прохождения уровня для варианта "Реализация проекта": 11 days 21:16:06.260986

# %%
#подсчитаем медианное время прохождения уровня для варианта реализации проекта

print('Медианное время прохождения уровня для варианта "Реализация проекта":',
      merge_game.query('type == "Реализация проекта"')['game_time'].median())
# Out:
# Медианное время прохождения уровня для варианта "Реализация проекта": 11 days 07:12:24

# %%
#добавим столбец с днем начала игры

merge_game['start_game_day'] = merge_game['start_game_date'].dt.date

# %%
#выделим день

merge_game['game_day'] = merge_game['game_time'] / np.timedelta64(1, 'D')
merge_game['game_day'] = merge_game['game_day'].round().astype('int') 

merge_game
# Out:
#                                    user_id       win_game_date  \
# 0     001d39dc-366c-4021-9604-6a3b9ff01e25 2020-05-12 07:40:47
# 1     003ee7e8-6356-4286-a715-62f22a18d2a1 2020-05-17 21:47:49
# 2     004074f8-251a-4776-922c-8348dca1a2f6 2020-05-16 19:57:40
# 3     00464e5e-28ed-4be6-bf44-517ef7b3937b 2020-05-15 16:02:01
# 4     0056c007-c082-43cc-bdef-afc49bca4cb9 2020-05-16 13:48:39
# ...                                    ...                 ...
# 5812  ffd002f3-3545-423e-8dba-0c6a2d48a3aa 2020-05-19 04:03:24
# 5813  ffe810f4-1a1f-464b-924d-6f120b0cb8df 2020-05-18 02:03:36
# 5814  ffef4fed-164c-40e1-bde1-3980f76d0fb5 2020-05-11 22:15:54
# 5815  fffb626c-5ab6-47c9-8113-2062a2f18494 2020-05-12 13:01:52
# 5816  ffff69cc-fec1-4fd3-9f98-93be1112a6b8 2020-05-25 03:55:06
#
#                           type     start_game_date        game_time  \
# 0     Победа над первым врагом 2020-05-05 21:02:05  6 days 10:38:42
# 1     Победа над первым врагом 2020-05-05 08:31:04 12 days 13:16:45
# 2     Победа над первым врагом 2020-05-04 01:07:35 12 days 18:50:05
# 3     Победа над первым врагом 2020-05-04 08:35:29 11 days 07:26:32
# 4     Победа над первым врагом 2020-05-10 11:49:47  6 days 01:58:52
# ...                        ...                 ...              ...
# 5812  Победа над первым врагом 2020-05-06 06:34:18 12 days 21:29:06
# 5813  Победа над первым врагом 2020-05-04 17:46:05 13 days 08:17:31
# 5814  Победа над первым врагом 2020-05-04 01:58:59  7 days 20:16:55
# 5815  Победа над первым врагом 2020-05-04 02:05:09  8 days 10:56:43
# 5816        Реализация проекта 2020-05-08 06:57:30 16 days 20:57:36
#
#      start_game_day  game_day
# 0        2020-05-05         6
# 1        2020-05-05        13
# 2        2020-05-04        13
# 3        2020-05-04        11
# 4        2020-05-10         6
# ...             ...       ...
# 5812     2020-05-06        13
# 5813     2020-05-04        13
# 5814     2020-05-04         8
# 5815     2020-05-04         8
# 5816     2020-05-08        17
#
# [5817 rows x 7 columns]

# %%
#посмотрим, как распределены уникальные пользователи

merge_game_time = merge_game.groupby('type').agg({'game_day':'mean'}).reset_index().sort_values(by = 'game_day', ascending = False)
merge_game_time
# Out:
#                        type   game_day
# 1        Реализация проекта  11.877278
# 0  Победа над первым врагом  11.108580

# %%
#построим график распределения 

plt.figure(figsize=(15,7))
ax = sns.barplot(data=merge_game_time, x='type', y='game_day')
plt.suptitle('Среднее время прохождения уровня')
plt.xlabel('Вариант прохождения уровня')
plt.ylabel('Дни')
sns.set_palette('dark') 

#добавим подписи

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 0.1,
            '{:1.2f}'.format(height),
            ha="center")

# %%
#построим график динамики времени прохождения уровня

merge_game.pivot_table(index ='start_game_day',
                                                columns = 'type', values = 'game_day').plot(grid = True, figsize = (15,7),title='Время прохождения уровня')
plt.xlabel('Старт игры')
plt.ylabel('Время прохождения уровня')
plt.show()

# %%
#построим гистограммы

merge_game.pivot_table(index ='start_game_day',
                                                columns = 'type', values = 'game_day').plot(kind = 'bar', grid = True, figsize = (24,10),title='Время прохождения уровня')

plt.xlabel('Старт игры')
plt.ylabel('Время прохождения уровня')
plt.show()

# %% [markdown]
# ### Вывод

# %% [markdown]
# На данном шаге подсчитаем среднее время прохождения уровня. Создадим вспомогательный столбец, в котором промаркируем, каким именно способом был завершен первый уровень - победой над врагом или реализацией проекта.
#
# В результате вычислений получаем:
#
#  - Среднее время прохождения уровня для варианта 'Победа над первым врагом' = 11 days 02:30:24
#  - Медианное время прохождения уровня для варианта "Победа над первым врагом" = 10 days 19:01:37
#
#  - Среднее время прохождения уровня для варианта "Реализация проекта": 11 days 21:16:06
#  - Медианное время прохождения уровня для варианта "Реализация проекта": 11 days 07:12:24
#
# Таким образом, пользователи завершают первый уровень быстрее, если выбирают вариант победить врага. Воинственность побеждает созидание.

# %% [markdown]
# ### Количество построек на каждого пользователя

# %%
#сгруппируем датасет по пользователю и посмотрим количество построек на каждого

building_count = game_actions.groupby('user_id').agg({'building_type': 'count'})
building_count.head()
# Out:
#                                       building_type
# user_id
# 0001f83c-c6ac-4621-b7f0-8a28b283ac30             13
# 00151b4f-ba38-44a8-a650-d7cf130a0105              9
# 001aaea6-3d14-43f1-8ca8-7f48820f17aa              4
# 001d39dc-366c-4021-9604-6a3b9ff01e25              8
# 002f508f-67b6-479f-814b-b05f00d4e995             12

# %%
#подсчитаем среднее значение количества построек

print('Cреднее значение количества построек на пользователя: {:.2f}'.format(building_count['building_type'].mean()))
# Out:
# Cреднее значение количества построек на пользователя: 9.43

# %%
#подсчитаем медианное значение количества построек

print('Медианное значение количества построек на пользователя:', building_count['building_type'].median())
# Out:
# Медианное значение количества построек на пользователя: 10.0

# %%
#отберем данные по пользователям, которые завершили уровень победой над врагом для создания фильтра

win_users_type = game_actions.query('type == "Победа над первым врагом"')
win_users_type.head()
# Out:
#            event_datetime             event building_type  \
# 6659  2020-05-04 19:47:29  finished_stage_1           NaN
# 13134 2020-05-05 13:22:09  finished_stage_1           NaN
# 15274 2020-05-05 18:54:37  finished_stage_1           NaN
# 16284 2020-05-05 21:27:29  finished_stage_1           NaN
# 19650 2020-05-06 06:02:22  finished_stage_1           NaN
#
#                                     user_id project_type  event_date  \
# 6659   ced7b368-818f-48f6-9461-2346de0892c5          NaN  2020-05-04
# 13134  7ef7fc89-2779-46ea-b328-9e5035b83af5          NaN  2020-05-05
# 15274  70db22b3-c2f4-43bc-94ea-51c8d2904a29          NaN  2020-05-05
# 16284  903fc9ef-ba97-4b12-9d5c-ac8d602fbd8b          NaN  2020-05-05
# 19650  58e077ba-feb1-4556-a5a0-d96bd04efa39          NaN  2020-05-06
#
#        event_week                      type
# 6659           19  Победа над первым врагом
# 13134          19  Победа над первым врагом
# 15274          19  Победа над первым врагом
# 16284          19  Победа над первым врагом
# 19650          19  Победа над первым врагом

# %%
#создадим список пользователей, которые прошли уровень через победу над врагом 

user_win = win_users_type['user_id']
user_win.head()
# Out:
# 6659     ced7b368-818f-48f6-9461-2346de0892c5
# 13134    7ef7fc89-2779-46ea-b328-9e5035b83af5
# 15274    70db22b3-c2f4-43bc-94ea-51c8d2904a29
# 16284    903fc9ef-ba97-4b12-9d5c-ac8d602fbd8b
# 19650    58e077ba-feb1-4556-a5a0-d96bd04efa39
# Name: user_id, dtype: object

# %%
#сформируем новый датасет, где для каждого события укажем к какому варианту прохождения уровня относится

game_actions_type = game_actions
game_actions_type.head()
# Out:
#        event_datetime     event  building_type  \
# 0 2020-05-04 00:00:01  building  assembly_shop
# 1 2020-05-04 00:00:03  building  assembly_shop
# 2 2020-05-04 00:00:16  building  assembly_shop
# 3 2020-05-04 00:00:16  building  assembly_shop
# 4 2020-05-04 00:00:35  building  assembly_shop
#
#                                 user_id project_type  event_date  event_week  \
# 0  55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-04          19
# 1  c07b1c10-f477-44dc-81dc-ec82254b1347          NaN  2020-05-04          19
# 2  6edd42cc-e753-4ff6-a947-2107cd560710          NaN  2020-05-04          19
# 3  92c69003-d60a-444a-827f-8cc51bf6bf4c          NaN  2020-05-04          19
# 4  cdc6bb92-0ccb-4490-9866-ef142f09139d          NaN  2020-05-04          19
#
#   type
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
game_actions_type.loc[(game_actions['event'] == "building") 
                  & (game_actions['user_id'].isin(user_win)), 'type'] = 'Победа над первым врагом'   

game_actions_type.loc[(game_actions['event'] == "building") 
                  & (game_actions['user_id'].isin(user_project)), 'type'] = 'Реализация проекта'

game_actions_type.loc[(game_actions['event'] == "building") 
                  & (~game_actions['user_id'].isin(user_project)) & (~game_actions['user_id'].isin(user_win)), 'type'] = 'Первый уровень не завершен'

game_actions_type.loc[(game_actions['event'] == "finished_stage_1") 
                  & (game_actions['user_id'].isin(user_project)), 'type'] = 'Реализация проекта'

game_actions_type.head()
# Out:
#        event_datetime     event  building_type  \
# 0 2020-05-04 00:00:01  building  assembly_shop
# 1 2020-05-04 00:00:03  building  assembly_shop
# 2 2020-05-04 00:00:16  building  assembly_shop
# 3 2020-05-04 00:00:16  building  assembly_shop
# 4 2020-05-04 00:00:35  building  assembly_shop
#
#                                 user_id project_type  event_date  event_week  \
# 0  55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-04          19
# 1  c07b1c10-f477-44dc-81dc-ec82254b1347          NaN  2020-05-04          19
# 2  6edd42cc-e753-4ff6-a947-2107cd560710          NaN  2020-05-04          19
# 3  92c69003-d60a-444a-827f-8cc51bf6bf4c          NaN  2020-05-04          19
# 4  cdc6bb92-0ccb-4490-9866-ef142f09139d          NaN  2020-05-04          19
#
#                          type
# 0  Первый уровень не завершен
# 1          Реализация проекта
# 2    Победа над первым врагом
# 3  Первый уровень не завершен
# 4    Победа над первым врагом

# %%
#посмотрим, как распределены уникальные пользователи

building_count = game_actions_type.groupby('type').agg({'building_type':'count','user_id':'nunique'}).reset_index().sort_values(by = 'user_id', ascending = False)
building_count['count'] = building_count['building_type'] / building_count['user_id']
building_count
# Out:
#                          type  building_type  user_id      count
# 0  Первый уровень не завершен          67170     7759   8.657043
# 1    Победа над первым врагом          37185     3951   9.411541
# 2          Реализация проекта          23601     1866  12.647910

# %%
#построим график распределения 

plt.figure(figsize=(15,7))
ax = sns.barplot(data=building_count, x='type', y='count')
plt.suptitle('Количество построек на каждого пользователя')
plt.xlabel('Вариант прохождения уровня')
plt.ylabel('Количество')
sns.set_palette('dark') 

#добавим подписи

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 0.1,
            '{:1.2f}'.format(height),
            ha="center")

# %%
#построим гистограммы

game_actions_type.pivot_table(index ='event_date',
                                                columns = 'type', values = 'building_type', aggfunc = 'count').plot(kind = 'bar', grid = True, figsize = (24,10),title='Количество построек')

plt.xlabel('Дата')
plt.ylabel('Количество построек')
plt.show()

# %% [markdown]
# ### Вывод

# %% [markdown]
# Подсчитаем количество построек на пользователя в разрезе варианта прохождения уровня:
#  - Реализация проекта: 12.65
#  - Победа над первым врагом: 9.41
#  - Первый уровень не завершён: 8.66

# %% [markdown]
# ### Сколько раз за день пользователи в среднем заходят в мобильное приложение

# %%
#рассчитаем количество сессий в день на каждого уникального пользователя

visits_per_user = game_actions.groupby('event_date').agg({'user_id': ['count', 'nunique']})

visits_per_user.columns = ['visits', 'users']
visits_per_user['visits_per_user'] = visits_per_user['visits'] / visits_per_user['users'] 
visits_per_user.mean()
# Out:
# visits             4110.272727
# users              2884.878788
# visits_per_user       1.333484
# dtype: float64

# %%
#распечатем столбец visits_per_user

visits_per_user['visits_per_user'].sort_values(ascending = False).head(10)
# Out:
# event_date
# 2020-05-10    1.649528
# 2020-05-09    1.564093
# 2020-05-08    1.528197
# 2020-05-07    1.470477
# 2020-05-06    1.448060
# 2020-06-04    1.428571
# 2020-05-05    1.418834
# 2020-05-04    1.394369
# 2020-05-12    1.370845
# 2020-05-11    1.365304
# Name: visits_per_user, dtype: float64

# %%
#рассчитаем максимальное количество сессий в день на каждого уникального пользователя

print('Максимальное количество сессий в день на каждого уникального пользователя: {:.2f}'.format(visits_per_user['visits_per_user'].max()))
# Out:
# Максимальное количество сессий в день на каждого уникального пользователя: 1.65

# %%
#рассчитаем минимальное количество сессий в день на каждого уникального пользователя

print('Минимальное количество сессий в день на каждого уникального пользователя: {:.2f}'. format(visits_per_user['visits_per_user'].min()))
# Out:
# Минимальное количество сессий в день на каждого уникального пользователя: 1.22

# %%
#построим график

visits_per_user['visits_per_user'].plot(grid = True, figsize = (24,10),title='Сколько раз за день пользователи в среднем заходят на сайт')
plt.xlabel('Дни')
plt.ylabel('Среднее количество сесий')
plt.show()

# %% [markdown]
# ### Вывод

# %% [markdown]
# Подсчитаем, сколько раз за день пользователи в среднем заходят в мобильное приложение.
#
#  - Среднее количество сессий в день = 4110
#  - Среднее количество уникальных пользователей в день = 2884
#  - Среднее количество сессий в день на каждого уникального пользователя = 1.33
#  - Максимальное количество сессий в день на каждого уникального пользователя = 1.65
#  - Минимальное количество сессий в день на каждого уникального пользователя = 1.22
#
# Построим график и отобразим среднее количество сессий в день. На графике максимальное количество сессий в день на каждого уникального пользователя приходится на 10 мая.

# %% [markdown]
# ### Показатели вовлечённости - DAU, WAU, Sticky Factor

# %%
#cгруппируем данные по уникальным пользователям и найдём среднее

#DAU - количество уникальных пользователей в день

dau_total = game_actions.groupby('event_date').agg({'user_id': 'nunique'}).mean()

print('Количество уникальных пользователей в день DAU:', int(dau_total))
# Out:
# Количество уникальных пользователей в день DAU: 2884

# %%
#посмотрим количество уникальных пользователей по дням

game_actions.groupby('event_date').agg({'user_id': 'nunique'}).sort_values(by = 'user_id', ascending = False).head()
# Out:
#             user_id
# event_date
# 2020-05-10     9219
# 2020-05-09     8394
# 2020-05-08     7891
# 2020-05-07     7384
# 2020-05-06     6854

# %%
#WAU - количество уникальных пользователей в неделю

wau_total = game_actions.groupby('event_week').agg({'user_id': 'nunique'}).mean()

print('Количество уникальных пользователей в неделю WAU:', int(wau_total))
# Out:
# Количество уникальных пользователей в неделю WAU: 6120

# %%
#рассчитаем метрику Sticky Factor за неделю

sticky_week = int(dau_total) / int(wau_total)
print('Вовлечённость аудитории Sticky Factor за неделю: {:.2%}'.format(sticky_week))
# Out:
# Вовлечённость аудитории Sticky Factor за неделю: 47.12%

# %%
#построим график количества уникальных пользователей в день DAU

game_actions.groupby('event_date').agg({'user_id': 'nunique'}).plot(grid = True, figsize = (15,7),title='Количество уникальных пользователей в день DAU')
plt.xlabel('Дни')
plt.xticks(np.arange(game_actions['event_date'].min(), game_actions['event_date'].max() + pd.to_timedelta('1 day'), pd.to_timedelta('1 day')), rotation = 45)
plt.ylabel('Количество уникальных пользователей в день DAU')
plt.show()

# %%
#построим график количества уникальных пользователей в неделю WAU

game_actions.groupby('event_week').agg({'user_id': 'nunique'}).plot(grid = True, figsize = (15,7),title='Количество уникальных пользователей в неделю WAU')
plt.xlabel('Недели')
plt.ylabel('Количество уникальных пользователей в неделю WAU')
plt.show()

# %% [markdown]
# ### Вывод

# %% [markdown]
# На данном шаге подсчитаем показатели вовлеченности - количество уникальных пользователей в день DAU, в неделю WAU, Sticky Factor за неделю.
#
#  - Количество уникальных пользователей в день DAU = 2884 пользователя
#
#  - Количество уникальных пользователей в неделю WAU = 6120 пользователей
#
#  - Вовлечённость аудитории Sticky Factor за неделю = 47.12%
#
# Посмотрим, сколько уникальных пользователей приходится на каждый день:
#
#  - на первом месте 2020-05-10 = 9219 уникальных пользователей
#  - на втором месте 2020-05-09 = 8394 уникальных пользователя
#  - на третьем месте 2020-05-08 = 7891 уникальный пользователь
#
# На графиках также видим, что самое большое количество пользователей приходится на 10 мая, и в целом пик приходится на "вторые майские" праздники. Видимо, в честь праздника пользователи решили сразиться с виртуальными врагами. Также по условию задачи нам представлены данные по первому уровню, получается, большинство пользователей прошли уровень к 10 мая, а далее перешли на второй уровень или ушли в отток, и количество пользователей в день закономерно снижается.

# %% [markdown]
# ### Коэффициент удержания Retention Rate

# %%
#возьмём дату, когда пользователь впервые проявил активность

first_date = game_actions.groupby(['user_id'])['event_date'].min()

#данные запишем в объект Series

first_date.name = 'first_date'
first_date.head()
# Out:
# user_id
# 0001f83c-c6ac-4621-b7f0-8a28b283ac30    2020-05-06
# 00151b4f-ba38-44a8-a650-d7cf130a0105    2020-05-06
# 001aaea6-3d14-43f1-8ca8-7f48820f17aa    2020-05-05
# 001d39dc-366c-4021-9604-6a3b9ff01e25    2020-05-05
# 002f508f-67b6-479f-814b-b05f00d4e995    2020-05-05
# Name: first_date, dtype: object

# %%
#объединим датафрейм и Series по столбцу 'user_id':

game_actions = game_actions.join(first_date, on='user_id') 

game_actions.head()
# Out:
#        event_datetime     event  building_type  \
# 0 2020-05-04 00:00:01  building  assembly_shop
# 1 2020-05-04 00:00:03  building  assembly_shop
# 2 2020-05-04 00:00:16  building  assembly_shop
# 3 2020-05-04 00:00:16  building  assembly_shop
# 4 2020-05-04 00:00:35  building  assembly_shop
#
#                                 user_id project_type  event_date  event_week  \
# 0  55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-04          19
# 1  c07b1c10-f477-44dc-81dc-ec82254b1347          NaN  2020-05-04          19
# 2  6edd42cc-e753-4ff6-a947-2107cd560710          NaN  2020-05-04          19
# 3  92c69003-d60a-444a-827f-8cc51bf6bf4c          NaN  2020-05-04          19
# 4  cdc6bb92-0ccb-4490-9866-ef142f09139d          NaN  2020-05-04          19
#
#                          type  first_date
# 0  Первый уровень не завершен  2020-05-04
# 1          Реализация проекта  2020-05-04
# 2    Победа над первым врагом  2020-05-04
# 3  Первый уровень не завершен  2020-05-04
# 4    Победа над первым врагом  2020-05-04

# %%
#выделим из столбцов event_date и first_date день

game_actions['event_day'] = game_actions['event_date'].astype('datetime64[D]')

game_actions['first_day'] = game_actions['first_date'].astype('datetime64[D]')

game_actions.head()
# Out:
#        event_datetime     event  building_type  \
# 0 2020-05-04 00:00:01  building  assembly_shop
# 1 2020-05-04 00:00:03  building  assembly_shop
# 2 2020-05-04 00:00:16  building  assembly_shop
# 3 2020-05-04 00:00:16  building  assembly_shop
# 4 2020-05-04 00:00:35  building  assembly_shop
#
#                                 user_id project_type  event_date  event_week  \
# 0  55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-04          19
# 1  c07b1c10-f477-44dc-81dc-ec82254b1347          NaN  2020-05-04          19
# 2  6edd42cc-e753-4ff6-a947-2107cd560710          NaN  2020-05-04          19
# 3  92c69003-d60a-444a-827f-8cc51bf6bf4c          NaN  2020-05-04          19
# 4  cdc6bb92-0ccb-4490-9866-ef142f09139d          NaN  2020-05-04          19
#
#                          type  first_date  event_day  first_day
# 0  Первый уровень не завершен  2020-05-04 2020-05-04 2020-05-04
# 1          Реализация проекта  2020-05-04 2020-05-04 2020-05-04
# 2    Победа над первым врагом  2020-05-04 2020-05-04 2020-05-04
# 3  Первый уровень не завершен  2020-05-04 2020-05-04 2020-05-04
# 4    Победа над первым врагом  2020-05-04 2020-05-04 2020-05-04

# %%
#рассчитаем lifetime пользователя в рамках когорты

game_actions['cohort_lifetime'] = game_actions['event_day'] - game_actions['first_day']

game_actions['cohort_lifetime'] = game_actions['cohort_lifetime'] / np.timedelta64(1, 'D')

game_actions['cohort_lifetime'] = game_actions['cohort_lifetime'].round().astype('int') 

game_actions.head()
# Out:
#        event_datetime     event  building_type  \
# 0 2020-05-04 00:00:01  building  assembly_shop
# 1 2020-05-04 00:00:03  building  assembly_shop
# 2 2020-05-04 00:00:16  building  assembly_shop
# 3 2020-05-04 00:00:16  building  assembly_shop
# 4 2020-05-04 00:00:35  building  assembly_shop
#
#                                 user_id project_type  event_date  event_week  \
# 0  55e92310-cb8e-4754-b622-597e124b03de          NaN  2020-05-04          19
# 1  c07b1c10-f477-44dc-81dc-ec82254b1347          NaN  2020-05-04          19
# 2  6edd42cc-e753-4ff6-a947-2107cd560710          NaN  2020-05-04          19
# 3  92c69003-d60a-444a-827f-8cc51bf6bf4c          NaN  2020-05-04          19
# 4  cdc6bb92-0ccb-4490-9866-ef142f09139d          NaN  2020-05-04          19
#
#                          type  first_date  event_day  first_day  \
# 0  Первый уровень не завершен  2020-05-04 2020-05-04 2020-05-04
# 1          Реализация проекта  2020-05-04 2020-05-04 2020-05-04
# 2    Победа над первым врагом  2020-05-04 2020-05-04 2020-05-04
# 3  Первый уровень не завершен  2020-05-04 2020-05-04 2020-05-04
# 4    Победа над первым врагом  2020-05-04 2020-05-04 2020-05-04
#
#    cohort_lifetime
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
#сгруппируем данные по когорте и lifetime

cohorts = game_actions.groupby(['first_day','cohort_lifetime']).agg({'user_id':'nunique'}).reset_index() 
cohorts.head()
# Out:
#    first_day  cohort_lifetime  user_id
# 0 2020-05-04                0     5860
# 1 2020-05-04                1     3021
# 2 2020-05-04                2     3204
# 3 2020-05-04                3     3412
# 4 2020-05-04                4     3564

# %%
#найдём исходное количество пользователей в когорте, возьмём их число на нулевой месяц

initial_users_count = cohorts[cohorts['cohort_lifetime'] == 0][['first_day', 'user_id']]
initial_users_count
# Out:
#      first_day  user_id
# 0   2020-05-04     5860
# 32  2020-05-05     3361
# 61  2020-05-06     1847
# 92  2020-05-07     1109
# 122 2020-05-08      688
# 149 2020-05-09      440
# 175 2020-05-10      271

# %%
#переименуем столбец uid в cohort_users

initial_users_count = initial_users_count.rename(columns={'user_id':'cohort_users'})

# %%
#объединим данные по когортам с исходным количеством пользователей в когорте

cohorts = cohorts.merge(initial_users_count,on='first_day') 
cohorts.head()
# Out:
#    first_day  cohort_lifetime  user_id  cohort_users
# 0 2020-05-04                0     5860          5860
# 1 2020-05-04                1     3021          5860
# 2 2020-05-04                2     3204          5860
# 3 2020-05-04                3     3412          5860
# 4 2020-05-04                4     3564          5860

# %%
#рассчитаем Retention Rate

cohorts['retention'] = cohorts['user_id']/cohorts['cohort_users'] 
cohorts.head()
# Out:
#    first_day  cohort_lifetime  user_id  cohort_users  retention
# 0 2020-05-04                0     5860          5860   1.000000
# 1 2020-05-04                1     3021          5860   0.515529
# 2 2020-05-04                2     3204          5860   0.546758
# 3 2020-05-04                3     3412          5860   0.582253
# 4 2020-05-04                4     3564          5860   0.608191

# %%
#построим сводную таблицу

retention_pivot = cohorts.pivot_table(
    index='first_day',
    columns='cohort_lifetime',
    values='retention',
    aggfunc='sum',
) 
retention_pivot
# Out:
# cohort_lifetime   0         1         2         3         4         5   \
# first_day
# 2020-05-04       1.0  0.515529  0.546758  0.582253  0.608191  0.641297
# 2020-05-05       1.0  0.536447  0.566201  0.612318  0.634633  0.687891
# 2020-05-06       1.0  0.519762  0.551164  0.605306  0.662696  0.434218
# 2020-05-07       1.0  0.507665  0.552750  0.599639  0.382326  0.400361
# 2020-05-08       1.0  0.482558  0.545058  0.351744  0.380814  0.414244
# 2020-05-09       1.0  0.479545  0.320455  0.338636  0.436364  0.390909
# 2020-05-10       1.0  0.254613  0.298893  0.328413  0.339483  0.413284
#
# cohort_lifetime        6         7         8         9   ...        22  \
# first_day                                                ...
# 2020-05-04       0.710068  0.465529  0.427304  0.405973  ...  0.007338
# 2020-05-05       0.472776  0.451056  0.408807  0.380839  ...  0.006843
# 2020-05-06       0.443963  0.434759  0.371413  0.332431  ...  0.004873
# 2020-05-07       0.459874  0.390442  0.329125  0.291253  ...  0.009919
# 2020-05-08       0.440407  0.376453  0.261628  0.312500  ...  0.004360
# 2020-05-09       0.420455  0.381818  0.270455  0.215909  ...  0.006818
# 2020-05-10       0.435424  0.369004  0.210332  0.210332  ...  0.003690
#
# cohort_lifetime        23        24        25        26        27        28  \
# first_day
# 2020-05-04       0.004949  0.003242  0.002048  0.001024  0.000683  0.000341
# 2020-05-05       0.004760  0.002678  0.002380  0.000893  0.000595  0.000298
# 2020-05-06       0.005414  0.002166  0.001624  0.001624  0.002166  0.000541
# 2020-05-07       0.006312  0.002705  0.005410  0.002705  0.002705  0.002705
# 2020-05-08       0.007267  0.001453       NaN  0.002907  0.001453       NaN
# 2020-05-09       0.002273  0.002273  0.002273       NaN       NaN       NaN
# 2020-05-10       0.003690       NaN       NaN       NaN       NaN       NaN
#
# cohort_lifetime        29        30        31
# first_day
# 2020-05-04       0.000171  0.000341  0.000341
# 2020-05-05            NaN       NaN       NaN
# 2020-05-06       0.000541  0.000541       NaN
# 2020-05-07       0.002705       NaN       NaN
# 2020-05-08            NaN       NaN       NaN
# 2020-05-09            NaN       NaN       NaN
# 2020-05-10            NaN       NaN       NaN
#
# [7 rows x 32 columns]

# %%
#построим тепловую карту

sns.set(style='white')
plt.figure(figsize=(24, 10))
retention_pivot.index = retention_pivot.index.strftime("%d/%m/%Y")
plt.title('Коэффициент Retention Rate')
sns.heatmap(retention_pivot.iloc[:, 1:], annot=True, fmt='.1%', linewidths=1, linecolor='gray')
plt.show()

# %%
#рассчитаем средний Retention Rate на второй день

print('Средний Retention Rate на второй день «жизни» когорт: {:.2%}'.format(retention_pivot[1].mean()))
# Out:
# Средний Retention Rate на второй день «жизни» когорт: 47.09%

# %% [markdown]
# ### Вывод

# %% [markdown]
# Рассчитаем коэффициент удержания  Retention Rate, применяя когортный анализ. Определим, сколько пользователей из когорты относительно их изначального числа вернулось в последующие периоды.
#
# Определим событие и период, на их основе сформируем когорту. Возьмём дату, когда пользователь впервые проявил активность.
# Период формирования когорты выберем один день.
#
# Сгруппируем данные по когорте и lifetime. Посчитаем для каждой когорты количество активных пользователей на определённый «день жизни». Найдём исходное количество пользователей в когорте,возьмём их число на нулевой месяц. Объединим данные по когортам с исходным количеством пользователей в когорте. Посчитаем Retention Rate и отобразим значения в сводной таблице.
#
# Построим тепловую карту, исключив при выводе нулевой месяц.
#
# На тепловой карте выделяется когорта 05/05/2020, коэффициент Retention Rate = 53,6%.
#
# Средний Retention Rate на второй день «жизни» когорт: 47.09%.
# Это хороший показатель, тк. по данным из интернета средний 1-дневный Retention равен 30-34% в зависимости от жанра для топ 25% мобильных игр.
#
# В целом у когорт прослеживается тренд на снижение Retention Rate, начиная с когорты.

# %% [markdown]
# ### Стоимость привлечения клиента CAC

# %%
#объединим дополнительные датасеты

ad_costs_source = pd.merge(user_source.groupby('source').agg('count'), ad_costs.groupby('source').agg('sum'), on = ['source'], how = 'inner').reset_index()
ad_costs_source
# Out:
#                     source  user_id         cost
# 0             facebook_ads     2726  2140.904643
# 1    instagram_new_adverts     3347  2161.441691
# 2            yandex_direct     4817  2233.111449
# 3  youtube_channel_reklama     2686  1068.119204

# %%
#подсчитаем стоимость привлечения САС

ad_costs_source['CAC'] = ad_costs_source['cost'] / ad_costs_source['user_id'] 
ad_costs_source
# Out:
#                     source  user_id         cost       CAC
# 0             facebook_ads     2726  2140.904643  0.785365
# 1    instagram_new_adverts     3347  2161.441691  0.645785
# 2            yandex_direct     4817  2233.111449  0.463590
# 3  youtube_channel_reklama     2686  1068.119204  0.397662

# %%
##подсчитаем среднее значение стоимости привлечения САС

ad_costs_source['CAC'].mean()
# Out:
# 0.5731002471448883

# %%
#построим график распределения САС

plt.figure(figsize=(15,7))
ax = sns.barplot(data= ad_costs_source, x='source', y='CAC')
plt.suptitle('Стоимость привлечения САС в разрезе источников')
plt.xlabel('Источник')
plt.ylabel('Стоимость привлечения')
sns.set_palette('dark') 

#добавим подписи

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 0.005,
            '{:.2f}'.format(height),
            ha="center")

# %% [markdown]
# ### Вывод

# %% [markdown]
# На данном шаге подсчитаем стоимость привлечения САС.
#
# Распределение стоимости привлечения пользователей по источникам трафика:
#
#  - facebook_ads  = 0.79
#  - instagram_new_adverts = 0.65
#  - yandex_direct = 0.46
#  - youtube_channel_reklama = 0.40
#
# Таким образом, самый дорогой способ привлечения пользователей через facebook_ads, а самый бюджетный - через youtube_channel_reklama.

# %% [markdown]
# ## Вывод

# %% [markdown]
# На данном шаге проведем исследовательский анализ данных.
#
#
# <b>Cреднее время прохождения уровня</b>
#
#
#  - Среднее время прохождения уровня для варианта 'Победа над первым врагом' = 11 days 02:30:24
#  - Медианное время прохождения уровня для варианта "Победа над первым врагом" = 10 days 19:01:37
#
#  - Среднее время прохождения уровня для варианта "Реализация проекта": 11 days 21:16:06
#  - Медианное время прохождения уровня для варианта "Реализация проекта": 11 days 07:12:24
#
# Таким образом, пользователи завершают первый уровень быстрее, если выбирают вариант победить врага. Воинственность побеждает созидание.
#
# <b>Количество построек на каждого пользователя</b>
#
#
#  - Cреднее значение количества построек на пользователя для всего датасета: 9.43
#  - Медианное значение количества построек на пользователя для всего датасета: 10.0
#
#  - Cреднее значение количества построек на пользователя в случае победы над врагом: 9.41
#  - Cреднее значение количества построек на пользователя в случае реализации проекта: 12.00
#
#
# <b>Сколько раз за день пользователи в среднем заходят в мобильное приложение</b>
#
#
#  - Среднее количество сессий в день = 4110
#  - Среднее количество уникальных пользователей в день = 2884
#  - Среднее количество сессий в день на каждого уникального пользователя = 1.33
#  - Максимальное количество сессий в день на каждого уникального пользователя = 1.65
#  - Минимальное количество сессий в день на каждого уникального пользователя = 1.22
#
#
# <b>Показатели вовлечённости - DAU, WAU, Sticky Factor</b>
#
#  - Количество уникальных пользователей в день DAU = 2884 пользователя
#
#  - Количество уникальных пользователей в неделю WAU = 6120 пользователей
#
#  - Вовлечённость аудитории Sticky Factor за неделю = 47.12%
#
# Посмотрим, сколько уникальных пользователей приходится на каждый день:
#
#  - на первом месте 2020-05-10 = 9219 уникальных пользователей
#  - на втором месте 2020-05-09 = 8394 уникальных пользователя
#  - на третьем месте 2020-05-08 = 7891 уникальный пользователь
#
# На графиках также видим, что самое большое количество пользователей приходится на 10 мая, и в целом пик приходится на "вторые майские" праздники. Видимо, в честь праздника пользователи решили сразиться с виртуальными врагами. Также по условию задачи нам представлены данные по первому уровню, получается, большинство пользователей прошли уровень к 10 мая, а далее перешли на второй уровень или ушли в отток, и количество пользователей в день закономерно снижается.
#
#
# <b>Коэффициент удержания Retention Rate</b>
#
#
# Средний Retention Rate на второй день «жизни» когорт: 47.09%. Это хороший показатель, тк. по данным из интернета средний 1-дневный Retention равен 30-34% в зависимости от жанра для топ 25% мобильных игр.
#
# В целом у когорт прослеживается тренд на снижение Retention Rate, начиная с когорты.
#
# <b>Стоимость привлечения клиента CAC</b>
#
# Распределение стоимости привлечения пользователей по источникам трафика:
#
#  - facebook_ads  = 0.79
#  - instagram_new_adverts = 0.65
#  - yandex_direct = 0.46
#  - youtube_channel_reklama = 0.40
#
# Таким образом, самый дорогой способ привлечения пользователей через facebook_ads, а самый бюджетный - через youtube_channel_reklama.

# %% [markdown]
# ## Проверка статистических гипотез

# %% [markdown]
# ### Гипотеза различия времени прохождения уровня

# %% [markdown]
# Нулевая гипотеза H0 - Среднее время прохождения уровня между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, совпадает.
#
#
# Альтернативная гипотеза H1 - Среднее время прохождения уровня между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, не совпадает.

# %%
#выделим время прохождения уровня в отдельный столбец и представим в виде одного числа

merge_game['game_day'] = merge_game['game_time'] / np.timedelta64(1, 'D')

merge_game['game_day'] = merge_game['game_day'].round().astype('int') 

merge_game.head()
# Out:
#                                 user_id       win_game_date  \
# 0  001d39dc-366c-4021-9604-6a3b9ff01e25 2020-05-12 07:40:47
# 1  003ee7e8-6356-4286-a715-62f22a18d2a1 2020-05-17 21:47:49
# 2  004074f8-251a-4776-922c-8348dca1a2f6 2020-05-16 19:57:40
# 3  00464e5e-28ed-4be6-bf44-517ef7b3937b 2020-05-15 16:02:01
# 4  0056c007-c082-43cc-bdef-afc49bca4cb9 2020-05-16 13:48:39
#
#                        type     start_game_date        game_time  \
# 0  Победа над первым врагом 2020-05-05 21:02:05  6 days 10:38:42
# 1  Победа над первым врагом 2020-05-05 08:31:04 12 days 13:16:45
# 2  Победа над первым врагом 2020-05-04 01:07:35 12 days 18:50:05
# 3  Победа над первым врагом 2020-05-04 08:35:29 11 days 07:26:32
# 4  Победа над первым врагом 2020-05-10 11:49:47  6 days 01:58:52
#
#   start_game_day  game_day
# 0     2020-05-05         6
# 1     2020-05-05        13
# 2     2020-05-04        13
# 3     2020-05-04        11
# 4     2020-05-10         6

# %%
#отберем данные для каждого уровня

p_win = merge_game[merge_game['type'] == "Победа над первым врагом"]['game_day']
p_project = merge_game[merge_game['type'] == "Реализация проекта"]['game_day']

# %%
#среднее каждой выборки

print('Среднее время прохождения уровня для данных p_win: {:.2f}'.format(merge_game[merge_game['type'] == "Победа над первым врагом"]['game_day'].mean()))

print('Среднее время прохождения уровня для данных p_project: {:.2f}'.format(merge_game[merge_game['type'] == "Реализация проекта"]['game_day'].mean()))
# Out:
# Среднее время прохождения уровня для данных p_win: 11.11
# Среднее время прохождения уровня для данных p_project: 11.88

# %%
#cравним дисперсии двух выборок

print('Значение дисперсии для выборки p_win: {:.2f}'.format(p_win.var()))

print('Значение дисперсии для выборки p_project: {:.2f}'.format(p_project.var()))

print('Разница дисперсий: {:.2%}'.format((p_win.var()-p_project.var())/ p_win.var()))

print()

#проверим гипотезу о равенстве среднего двух генеральных совокупностей

results = st.ttest_ind(p_win, p_project, equal_var = False)

#критический уровень статистической значимости

alpha = 0.05 

#для проверки используем критерий p-value

print('p-значение:', results.pvalue)

#сравним получившееся p-значение с заданным уровнем статистической значимости

if results.pvalue < alpha:
    print('Принимаем альтернативную гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# Значение дисперсии для выборки p_win: 16.85
# Значение дисперсии для выборки p_project: 13.35
# Разница дисперсий: 20.79%
#
# p-значение: 7.444371631883923e-13
# Принимаем альтернативную гипотезу

# %% [markdown]
# ### Гипотеза различия количества построенных зданий

# %% [markdown]
# Нулевая гипотеза H0 - Среднее количество построенных зданий между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, совпадает.
#
#
# Альтернативная гипотеза H1 - Среднее количество построенных зданий между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, не совпадает.

# %%
#отберем все данные по пользователям, которые завершили уровень победой над врагом

win_building = game_actions_type[game_actions_type['user_id'].isin(user_project)]

#подсчитаем количество построенных зданий для каждого пользователя

building_type_win = win_building.groupby('user_id').agg({'building_type':'count'}).reset_index()
building_type_win.head()
# Out:
#                                 user_id  building_type
# 0  006380d6-67a6-45de-ab1e-6eb54ad8dbe8             11
# 1  00be7371-fa79-4fbd-b8e7-8ba32e3f8f82             12
# 2  00c2b9f2-2615-439c-aed0-6974e4c6c1c1             11
# 3  00de2809-403e-4476-a2f7-ca1b11700190             13
# 4  00e83261-5fd4-4939-9616-802b5a0202c6             13

# %%
#отберем все данные по пользователям, которые завершили уровень реализацией проекта

project_building = game_actions_type[game_actions_type['user_id'].isin(user_win)]

#подсчитаем количество построенных зданий для каждого пользователя

building_type_project = project_building.groupby('user_id').agg({'building_type':'count'}).reset_index()
building_type_project.head()
# Out:
#                                 user_id  building_type
# 0  001d39dc-366c-4021-9604-6a3b9ff01e25              8
# 1  003ee7e8-6356-4286-a715-62f22a18d2a1              8
# 2  004074f8-251a-4776-922c-8348dca1a2f6             12
# 3  00464e5e-28ed-4be6-bf44-517ef7b3937b              8
# 4  0056c007-c082-43cc-bdef-afc49bca4cb9              3

# %%
#отберем данные для каждого уровня

p_win_building = building_type_win['building_type']
p_project_building = building_type_project['building_type']

# %%
#подсчитаем среднее значение количества построек

print('Cреднее значение количества построек на пользователя для данных p_win_building: {:.2f}'.format(building_type_win['building_type'].mean()))

print('Cреднее значение количества построек на пользователя для данных p_project_building: {:.2f}'.format(building_type_project['building_type'].mean()))
# Out:
# Cреднее значение количества построек на пользователя для данных p_win_building: 12.65
# Cреднее значение количества построек на пользователя для данных p_project_building: 9.41

# %%
#cравним дисперсии двух выборок

print('Значение дисперсии для выборки p_win_building:', p_win_building.var())

print('Значение дисперсии для выборки p_project_building:', p_project_building.var())

print('Разница дисперсий: {:.2%}'.format((p_project_building.var()-p_win_building.var())/ p_project_building.var()))

print()

#проверим гипотезу о равенстве среднего двух генеральных совокупностей

results = st.ttest_ind(p_win_building, p_project_building, equal_var = False)

#критический уровень статистической значимости

alpha = 0.05 

#для проверки используем критерий p-value

print('p-значение:', results.pvalue)

#сравним получившееся p-значение с заданным уровнем статистической значимости

if results.pvalue < alpha:
    print('Принимаем альтернативную гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# Значение дисперсии для выборки p_win_building: 4.676502331836245
# Значение дисперсии для выборки p_project_building: 9.360717395692165
# Разница дисперсий: 50.04%
#
# p-значение: 0.0
# Принимаем альтернативную гипотезу

# %% [markdown]
# ## Вывод

# %% [markdown]
# На данном шаге проверим статистические гипотезы.
#
#
# <b>Гипотеза различия времени прохождения уровня</b>
#
#    - Нулевая гипотеза H0 - Среднее время прохождения уровня между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, совпадает.
#    - Альтернативная гипотеза H1 - Среднее время прохождения уровня между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, не совпадает.
#     - p-значение: 7.444371631883923e-13. Принимаем альтернативную гипотезу
#
# <b>Гипотеза различия количества построенных зданий</b>
#
#    - Нулевая гипотеза H0 - Среднее количество построенных зданий между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, совпадает.
#    - Альтернативная гипотеза H1 - Среднее количество построенных зданий между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, не совпадает.
#     - p-значение: 0.0. Принимаем альтернативную гипотезу

# %% [markdown]
# ## Формулирование модели монетизации

# %% [markdown]
# В соотвествии с проведённым выше исследованием сформулируем модель монетизации.
#
# Выбор того или иного варианта прохождения игры - реализация проекта или победа над первым врагом - не оказывает принципиального влияния на игру, время прохождения игры и количество построек отличается незначительно, значит, формулировки будут актуальны для любого варианта прохождения игры.
#
# По условию предполагается, что в приложении будет происходить показ рекламы на экране с выбором типа объекта для постройки. Предлагаем придерживаться данной концепции.
#
#  - Стоимость привлечения клиента считаем равной 0.57.
#  - Cреднее значение количества построек на пользователя будем считать равным 10.
#
#  - Если мы будем показывать рекламу на каждом экране с выбором типа объекта для постройки, значит стоимость рекламы должна  составлять не менее 0.57/10 = 0.06, чтобы окупить расходы. С учетом ожидаемого 10% оттока пользователей из-за показа рекламы (данные из интернета), стоимость рекламы должна составлять не менее 0.06/0.9 = 0.066
#
#  - Если мы будем показывать рекламу через раз, а не на каждом экране с выбором типа объекта для постройки, значит стоимость рекламы должна  составлять не менее 0.57/5 = 0.114, чтобы окупить расходы. С учетом ожидаемого 10% оттока пользователей из-за показа рекламы (данные из интернета), стоимость рекламы должна составлять не менее 0.114/0.9 = 0.126
#
# Таким образом, стоимость рекламы должна составлять:
#  - 0.066 - если показывать рекламу на каждом экране постройки
#  - 0.126 - если показывать не на каждом экране, а через раз

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В рамках данного проекта необходимо было проанализировать поведение первых пользователей мобильной игры, выявить особенности поведения и выбрать для бизнеса оптимальное время для запуска рекламы. По условию задачи создатели игры планируют показывать её на экране выбором постройки.
#
# В качестве исходных данных были предоставлен датасет с данными первых пользователей приложения и два дополнительных датасета с информацией о рекламных активностях.
#
# Целевое событие - завершение первого уровня.
#
# Исследование проводили в несколько шагов.
#
# *Подготовка данных к исследованию*
#
# На первом шаге открыли файлы с исходными данными и изучили общую информацию по каждой таблице. Проверили таблицы на наличие пропущенных значений и дубликатов.
#
#
#
# На данном шаге рассмотрим каждый датасет и каждый столбец отдельно и подготовим данные к исследованию.
#
# Проверим на наличие дубликатов каждый датасет. Количество дубликатов в таблице `game_actions` составляет 1, исключим данный дубликат. Количество дубликатов в таблицах `ad_costs.csv` и `user_source.csv` равно нулю.
#
#
# <b>Таблица `game_actions`:</b>
#
#  - Столбец `event_datetime` - время события
#
#   - Cуммарное количество пропусков для столбца `event_datetime` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Скорректируем формат отображения дат для столбца и выделим дату в отдельный столбец.
#   - Период, за который представлены данные в столбце, - с 4 мая по 5 июня включительно:
#     - Максимальное значение даты и времени - 2020-05-04 00:00:01
#     - Максимальное значение даты и времени - 2020-06-05 12:32:49
#     - При этом по условию задачи сказано, что в датасете содержатся данные первых пользователей приложения — когорты пользователей, которые начали пользоваться приложением в период с 4 по 10 мая включительно.
#
#
#  - Столбец `event` - событие
#
#   - Cуммарное количество пропусков для столбца `event` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
#   - Посмотрим, как распределены данные по событиям:
#     - building (объект построен) = 127956 значений
#     - finished_stage_1 (первый уровень завершён) = 5817 значений
#     - project (проект завершён) = 1866 значений
#
#   - Также посмотрим, как распределены уникальные пользователи по событиям:
#     - building (объект построен) = 13576 пользователей
#     - finished_stage_1 (первый уровень завершён) = 5817 пользователей
#     - project (проект завершён) = 1866 пользователей
#
#   - По условию задачи в датасете представлены данные по игре пользователей на первом уровне, и завершение первого уровня требует от игрока выполнения одного из двух условий:
#       - Победа над первым врагом
#       - Реализация проекта - разработка орбитальной сборки спутников
#
#   - Целевое событие - завершение первого уровня. Таким образом, первый уровень завершён finished_stage_1 у 5817 пользователей. Процент завершивших первый уровень составляет 42.85%. Из них 1866 пользователей завершили уровень через реализацию проекта project (разработку орбитальной сборки спутников). А 5817 - 1866  = 3951 завершили уровень через победу над первым врагом. Т.е. способ прохождения уровня через победу над врагом пользователи предпочитают больше, чем разработку орбитальной сборки спутников.
#
#
#  - Столбец `building_type` - тип здания
#
#   - Суммарное количество пропусков для столбца `building_type` равно 7683. Корректировки вносить не будем. Тип данных не меняем.
#
#   - Посмотрим, как распределены данные по типам зданий:
#     - spaceport (космопорт) = 59325 значений
#     - assembly_shop (сборочный цех) = 54494 значения
#     - research_center (исследовательский центр) = 14137 значений
#
#   - Также посмотрим, как распределены уникальные пользователи по типам зданий:
#     - spaceport (космопорт) = 13576 пользователей
#     - assembly_shop (сборочный цех) = 13231 пользователь
#     - research_center (исследовательский центр) = 7671 пользователь
#
#
#  - Столбец `user_id` - идентификатор пользователя
#
#   - Cуммарное количество пропусков для столбца `user_id` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#   - Количество уникальных пользователей - 13576.
#
#
#  - Столбец `project_type` - тип реализованного проекта
#
#   - Cуммарное количество пропусков для столбца `project_type` равно 133773. Корректировки вносить не будем. Тип данных не меняем.
#
#   - В столбце представлен только один тип реализованного объекта:
#     - satellite_orbital_assembly (разработка орбитальной сборки спутников) = 1866
#
#
#
# <b>Таблица `game_actions`:</b>
#
#
#  - Столбец `source` - источник трафика
#
#   - Cуммарное количество пропусков для столбца `source` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
#   - Уникальные источники трафика:
#     - yandex_direct = 7
#     - instagram_new_adverts = 7
#     - youtube_channel_reklama = 7
#     - facebook_ads = 7
#
#
#  - Столбец `day` - день, в который был совершен клик по объявлению
#
#   - Cуммарное количество пропусков для столбца `day` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Скорректируем формат отображения дат для столбца.
#   - Количество уникальных значений в столбце = 7.
#
#   - Период, за который представлены данные в столбце, - с 3 мая по 9 мая 2020 включительно:
#     - Максимальное значение даты и времени - 2020-05-03
#     - Максимальное значение даты и времени - 2020-05-09
#
#  - Столбец `cost` - стоимость кликов
#
#   - Cуммарное количество пропусков для столбца `cost` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается.
#
#     - Максимальная стоимость кликов =  969.13
#     - Минимальная стоимость кликов = 23.31
#     - Среднее значение стоимости кликов = 271.55
#     - Медианное значение стоимости кликов = 160.05
#
#   - На гистограмме распределение не похоже на нормальное, на диаграмме размаха отображаются выбросы. Ориентироваться будем на медианное значение.
#
#   - Распределение стоимости кликов по источникам трафика:
#      - yandex_direct =  2233.11
#      - instagram_new_adverts = 2161.44
#      - facebook_ads	 = 2140.90
#      - youtube_channel_reklama = 1068.11
#
#  - Таким образом, самая большая суммарная стоимость кликов приходится на источник трафика yandex_direct, на втором месте instagram_new_adverts, на третьем месте facebook_ads, а меньше всего  - на  youtube_channel_reklama.
#
#
# <b>Таблица `user_source`:</b>
#
#  - Столбец `user_id` - идентификатор пользователя
#
#   - Cуммарное количество пропусков для столбца `user_id` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
#   - Количество уникальных пользователей - 13576.
#
#
#  - Столбец `source` - источник, с которого пришёл пользователь, установивший приложение
#
#  - Cуммарное количество пропусков для столбца `source` равно нулю, пропущенных значений нет, подозрительных значений не наблюдается. Корректировки вносить не будем. Тип данных не меняем.
#
#  - Распределение уникальных пользователей по источникам трафика:
#
#    - yandex_direct =  4817 пользователей
#    - instagram_new_adverts = 3347 пользователей
#    - facebook_ads	 = 2726 пользователей
#    - youtube_channel_reklama = 2686 пользователей
#  - Аналогично распределению стоимости кликов, больше всего пользователей приходится на источник трафика yandex_direct, на втором месте instagram_new_adverts, на третьем месте facebook_ads, а меньше всего  - на  youtube_channel_reklama.
#
#
#
# *Исследовательский анализ данных*
#
# На данном шаге проведем исследовательский анализ данных.
#
#
# <b>Cреднее время прохождения уровня</b>
#
#
#  - Среднее время прохождения уровня для варианта 'Победа над первым врагом' = 11 days 02:30:24
#  - Медианное время прохождения уровня для варианта "Победа над первым врагом" = 10 days 19:01:37
#
#  - Среднее время прохождения уровня для варианта "Реализация проекта": 11 days 21:16:06
#  - Медианное время прохождения уровня для варианта "Реализация проекта": 11 days 07:12:24
#
# Таким образом, пользователи завершают первый уровень быстрее, если выбирают вариант победить врага. Воинственность побеждает созидание.
#
# <b>Количество построек на каждого пользователя</b>
#
#
# Количество построек на пользователя в разрезе варианта прохождения уровня:
#  - Реализация проекта: 12.65
#  - Победа над первым врагом: 9.41
#  - Первый уровень не завершён: 8.66
#
#
# <b>Сколько раз за день пользователи в среднем заходят в мобильное приложение</b>
#
#
#  - Среднее количество сессий в день = 4110
#  - Среднее количество уникальных пользователей в день = 2884
#  - Среднее количество сессий в день на каждого уникального пользователя = 1.33
#  - Максимальное количество сессий в день на каждого уникального пользователя = 1.65
#  - Минимальное количество сессий в день на каждого уникального пользователя = 1.22
#
#
# <b>Показатели вовлечённости - DAU, WAU, Sticky Factor</b>
#
#  - Количество уникальных пользователей в день DAU = 2884 пользователя
#
#  - Количество уникальных пользователей в неделю WAU = 6120 пользователей
#
#  - Вовлечённость аудитории Sticky Factor за неделю = 47.12%
#
# Посмотрим, сколько уникальных пользователей приходится на каждый день:
#
#  - на первом месте 2020-05-10 = 9219 уникальных пользователей
#  - на втором месте 2020-05-09 = 8394 уникальных пользователя
#  - на третьем месте 2020-05-08 = 7891 уникальный пользователь
#
# На графиках также видим, что самое большое количество пользователей приходится на 10 мая, и в целом пик приходится на "вторые майские" праздники. Видимо, в честь праздника пользователи решили сразиться с виртуальными врагами. Также по условию задачи нам представлены данные по первому уровню, получается, большинство пользователей прошли уровень к 10 мая, а далее перешли на второй уровень или ушли в отток, и количество пользователей в день закономерно снижается.
#
#
# <b>Коэффициент удержания Retention Rate</b>
#
#
# Средний Retention Rate на второй день «жизни» когорт: 47.09%. Это хороший показатель, тк. по данным из интернета средний 1-дневный Retention равен 30-34% в зависимости от жанра для топ 25% мобильных игр.
#
# В целом у когорт прослеживается тренд на снижение Retention Rate, начиная с когорты.
#
# <b>Стоимость привлечения клиента CAC</b>
#
# Распределение стоимости привлечения пользователей по источникам трафика:
#
#  - facebook_ads  = 0.79
#  - instagram_new_adverts = 0.65
#  - yandex_direct = 0.46
#  - youtube_channel_reklama = 0.40
#
# Таким образом, самый дорогой способ привлечения пользователей через facebook_ads, а самый бюджетный - через youtube_channel_reklama.
#
#
#
# *Проверка статистических гипотез*
#
# <b>Гипотеза различия времени прохождения уровня</b>
#
#    - Нулевая гипотеза H0 - Среднее время прохождения уровня между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, совпадает.
#    - Альтернативная гипотеза H1 - Среднее время прохождения уровня между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, не совпадает.
#     - p-значение: 7.444371631883923e-13. Принимаем альтернативную гипотезу
#
# <b>Гипотеза различия количества построенных зданий</b>
#
#    - Нулевая гипотеза H0 - Среднее количество построенных зданий между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, совпадает.
#    - Альтернативная гипотеза H1 - Среднее количество построенных зданий между пользователями, которые заканчивают уровень через реализацию проекта, и пользователями, которые заканчивают уровень победой над другим игроком, не совпадает.
#     - p-значение: 0.0. Принимаем альтернативную гипотезу
#
#
# <b>Модель монетизации</b>
#
#
# Выбор того или иного варианта прохождения игры - реализация проекта или победа над первым врагом - не оказывает принципиального влияния на игру, время прохождения игры и количество построек отличается незначительно, значит, формулировки будут актуальны для любого варианта прохождения игры.
#
# По условию предполагается, что в приложении будет происходить показ рекламы на экране с выбором типа объекта для постройки. Предлагаем придерживаться данной концепции.
#
#  - Стоимость привлечения клиента считаем равной 0.57.
#  - Cреднее значение количества построек на пользователя будем считать равным 10.
#
#  - Если мы будем показывать рекламу на каждом экране с выбором типа объекта для постройки, значит стоимость рекламы должна  составлять не менее 0.57/10 = 0.06, чтобы окупить расходы. С учетом ожидаемого 10% оттока пользователей из-за показа рекламы (данные из интернета), стоимость рекламы должна составлять не менее 0.06/0.9 = 0.066
#
#  - Если мы будем показывать рекламу через раз, а не на каждом экране с выбором типа объекта для постройки, значит стоимость рекламы должна  составлять не менее 0.57/5 = 0.114, чтобы окупить расходы. С учетом ожидаемого 10% оттока пользователей из-за показа рекламы (данные из интернета), стоимость рекламы должна составлять не менее 0.114/0.9 = 0.126
#
# Таким образом, стоимость рекламы должна составлять:
#  - 0.066 - если показывать рекламу на каждом экране постройки
#  - 0.126 - если показывать не на каждом экране, а через раз

# %%
#выгрузим файл для дашборда

game_actions_type.to_csv('game_actions_type.csv', index=False)

# %%
user_source.to_csv('user_source.csv', index=False)
